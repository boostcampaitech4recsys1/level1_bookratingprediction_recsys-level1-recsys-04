# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import re
path = './data/'
p1= pd.read_csv(path+'users.csv')
p2= pd.read_csv(path+'books.csv')
p3= pd.read_csv(path+'train_ratings.csv')
p4= pd.read_csv(path+'sample_submission.csv')
p5= pd.read_csv(path+'test_ratings.csv') # test와 sample은 완벽하게 동일하다.

#조금 전처리됨
p6= pd.read_csv('/opt/ml/input/code/pre_users.csv')

users  =p6.copy()
books  =p2.copy()
train  =p3.copy()
sample =p4.copy()
test   =p5.copy()

print('users shape: ', users.shape) 
print(users.columns)#유저id, 지역, 나이
print('books shape: ', books.shape)
print(books.columns)#isbn(책번호), 제목, 저자, 출판년도, 출판사, img주소, 언어, 범주, 요약, img경로
print('train shape: ', train.shape) 
print(train.columns)# 유저 id, 책isbn, 평점
# Out:
# users shape:  (68092, 5)
# Index(['user_id', 'age', 'city', 'state', 'country'], dtype='object')
# books shape:  (149570, 10)
# Index(['isbn', 'book_title', 'book_author', 'year_of_publication', 'publisher',
#        'img_url', 'language', 'category', 'summary', 'img_path'],
#       dtype='object')
# train shape:  (306795, 3)
# Index(['user_id', 'isbn', 'rating'], dtype='object')

# %%
#re.sub(정규표현식, 치환 문자, 대상 문자열) replace해준다.
#\W는 알파벳, 숫자, _가 아닌 모든 문자, 즉 특수문자! +는 반복이 있을 수 있다는 것을 뜻한다.
books.loc[books[books['category'].notnull()].index, 'category'] = \
	books[books['category'].notnull()]['category'].apply(lambda x: re.sub('[\W_]+',' ',x).strip())
books['category'] = books['category'].str.lower()
books['category'] = books['category'].fillna('1')
books.drop(columns=['img_url', 'img_path'], inplace=True, errors='ignore')
# print(books.sample(5))
train = pd.merge(train, users)
train = pd.merge(train, books)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306795 entries, 0 to 306794
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   user_id              306795 non-null  int64
#  1   isbn                 306795 non-null  object
#  2   rating               306795 non-null  int64
#  3   age                  214133 non-null  float64
#  4   city                 299787 non-null  object
#  5   state                298103 non-null  object
#  6   country              300283 non-null  object
#  7   book_title           306795 non-null  object
#  8   book_author          306795 non-null  object
#  9   year_of_publication  306795 non-null  float64
#  10  publisher            306795 non-null  object
#  11  language             187711 non-null  object
#  12  category             306795 non-null  object
#  13  summary              187711 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 35.1+ MB

# %%
tmp = train['category'].value_counts().to_dict()
train_category = pd.DataFrame(list(tmp.items()), columns=('category', 'count'))
category_one = train_category[train_category['count'] == 1]
category_one
# Out:
#                                              category  count
# 1873                                      holy spirit      1
# 1874                                        pregnancy      1
# 1875                                        evolution      1
# 1876                                      dayton tenn      1
# 1877                               unix computer file      1
# ...                                               ...    ...
# 3711                                          hasidim      1
# 3712                                           aggada      1
# 3713                               american loyalists      1
# 3714                                chemical industry      1
# 3715  authors canadian english 20th century biography      1
#
# [1843 rows x 2 columns]

# %%
tmp = books['category'].value_counts().to_dict()
books_category = pd.DataFrame(list(tmp.items()), columns=('category', 'count'))

# %%
tmp_category = books['category'].copy()
categories = ['garden','crafts','physics','adventure','music','fiction','nonfiction','science','science fiction','social','homicide',
 'sociology','disease','religion','christian','philosophy','psycholog','mathemat','agricult','environmental',
 'business','poetry','drama','literary','travel','motion picture','children','cook','literature','electronic',
 'humor','animal','bird','photograph','computer','house','ecology','family','architect','camp','criminal','language','india',
 'history']

for category in categories:
	tmp_category=tmp_category.where(tmp_category.str.contains(category) == False, category)
tmp_category.str.contains('fiction')
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 149565    False
# 149566    False
# 149567    False
# 149568     True
# 149569    False
# Name: category, Length: 149570, dtype: bool

# %%
print(tmp_category[tmp_category.str.contains('animal')].count())
print(tmp_category[tmp_category.str.contains('bird')].count())
# Out:
# 224
# 26

# %%
#차라리 직접 범주 분류를 해보자. 
#학습셋과 책셋에서의 상위권들을 보고 비교해보자. 
tmp = [1, 5, 10, 20, 30, 40, 50, 100, 200]
for i in tmp:
	print(f'책 데이터 상위 {i}개의 범주의 지분')
	print(books_category[:i]['count'].sum() / books_category['count'].sum())
# books_category[:50]
# Out:
# 책 데이터 상위 1개의 범주의 지분
# 0.4603262686367587
# 책 데이터 상위 5개의 범주의 지분
# 0.7551982349401618
# 책 데이터 상위 10개의 범주의 지분
# 0.8002674333088187
# 책 데이터 상위 20개의 범주의 지분
# 0.8533395734438725
# 책 데이터 상위 30개의 범주의 지분
# 0.8853045396804172
# 책 데이터 상위 40개의 범주의 지분
# 0.9064585144079695
# 책 데이터 상위 50개의 범주의 지분
# 0.9166610951393996
# 책 데이터 상위 100개의 범주의 지분
# 0.9359430367052216
# 책 데이터 상위 200개의 범주의 지분
# 0.949080698000936

# %%
#잊지말자. 책 데이터를 정제한다면 이후에는 학습데이터에도 반영해줘야한다.
books['high_category'] = books['category'].copy()

# %%
print('juvenile fiction',train[train['category'] =='juvenile fiction']['rating'].describe()[:3])
print('juvenile nonfiction',train[train['category'] =='juvenile nonfiction']['rating'].describe()[:3])
#소설 비소설보다는 청소년용인게 중요하지 않을까?
# Out:
# juvenile fiction count    12099.000000
# mean         7.519712
# std          2.383750
# Name: rating, dtype: float64
# juvenile nonfiction count    1660.000000
# mean        7.323494
# std         2.557274
# Name: rating, dtype: float64

# %%
#쳥소년용은 청소년용으로 퉁치기
lst = ['juvenile', 'young adult']
lst = '|'.join(lst)
books['high_category'].where(books['high_category'].str.contains(lst)==False, 'juvenile', inplace=True)

# %%
books['high_category'].value_counts() # 효과적으로 합쳐졌다.
# Out:
# 1                                                  68851
# fiction                                            33016
# juvenile                                            7318
# biography autobiography                             3326
# history                                             1927
#                                                    ...
# gone with the wind motion picture 1939                 1
# disguise                                               1
# country lawyers                                        1
# humorous stories brazilian                             1
# authors canadian english 20th century biography        1
# Name: high_category, Length: 4094, dtype: int64

# %%
# books[books['category'].str.contains('crim')]

# %% [markdown]
# # 잠시 실험. k-동건 클러스터링 말고 다른 방법이 있는가?

# %%
corr = train.corr()

plt.figure(figsize=(20,15))
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(data = corr, annot = True, mask=mask, fmt='.2f', linewidths=1., cmap='RdYlBu_r')
plt.show()
# Out:
# /tmp/ipykernel_86700/3342971300.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = train.corr()
# /tmp/ipykernel_86700/3342971300.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %%
# !pip install kmodes
#이게 진짜 맞다니
# Out:
# Requirement already satisfied: kmodes in /opt/conda/lib/python3.8/site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.10.4 in /opt/conda/lib/python3.8/site-packages (from kmodes) (1.23.4)
# Requirement already satisfied: scipy>=0.13.3 in /opt/conda/lib/python3.8/site-packages (from kmodes) (1.9.3)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/conda/lib/python3.8/site-packages (from kmodes) (1.1.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.8/site-packages (from kmodes) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn>=0.22.0->kmodes) (3.1.0)

# %%
tmp = books.drop(columns=['language', 'summary'], errors='ignore')
tmp
# Out:
#               isbn                                         book_title  \
# 0       0002005018                                       Clara Callan
# 1       0060973129                               Decision in Normandy
# 2       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3       0399135782                             The Kitchen God's Wife
# 4       0425176428  What If?: The World's Foremost Military Histor...
# ...            ...                                                ...
# 149565  067161746X  The Bachelor Home Companion: A Practical Guide...
# 149566  0767907566  All Elevations Unknown: An Adventure in the He...
# 149567  0884159221  Why stop?: A guide to Texas historical roadsid...
# 149568  0912333022  The Are You Being Served? Stories: 'Camping In...
# 149569  1569661057  Dallas Street Map Guide and Directory, 2000 Ed...
#
#                  book_author  year_of_publication                 publisher  \
# 0       Richard Bruce Wright               2001.0     HarperFlamingo Canada
# 1               Carlo D'Este               1991.0           HarperPerennial
# 2           Gina Bari Kolata               1999.0      Farrar Straus Giroux
# 3                    Amy Tan               1991.0          Putnam Pub Group
# 4              Robert Cowley               2000.0  Berkley Publishing Group
# ...                      ...                  ...                       ...
# 149565         P.J. O'Rourke               1987.0              Pocket Books
# 149566          Sam Lightner               2001.0            Broadway Books
# 149567         Claude Dooley               1985.0           Lone Star Books
# 149568          Jeremy Lloyd               1997.0                Kqed Books
# 149569                Mapsco               1999.0  American Map Corporation
#
#          category high_category
# 0       actresses     actresses
# 1       1940 1949     1940 1949
# 2         medical       medical
# 3         fiction       fiction
# 4         history       history
# ...           ...           ...
# 149565      humor         humor
# 149566     nature        nature
# 149567          1             1
# 149568    fiction       fiction
# 149569          1             1
#
# [149570 rows x 7 columns]

# %%
# from kmodes.kmodes import KModes
# cost = []
# K = range(1, 7)
# for num in K:
#     kmode = KModes(n_clusters = num, n_init = 3)
#     kmode.fit_predict(tmp)
#     cost.append(kmode.cost_)

# plt.plot(K, cost, 'bx-')
# plt.xlabel('number of clusters')
# plt.ylabel('cost')
# plt.title('elbow method for finding optimal K')
# plt.show()

# %%
# kmode = KModes(n_clusters = 20, n_init = 3)
# clusters = kmode.fit_predict(tmp)
# tmp['clusters'] = clusters

# %%
# lst = [0, 5, 10, 15]
# for i in lst:
# 	print(i, '번째 클러스터')
# 	print(tmp[tmp['clusters'] == i]['high_category'].value_counts())

# %%
len(books[books['category'] == 'fiction'])
# Out:
# 33016

# %%
# kmode = KModes(n_clusters = 2, n_init = 3)
# clusters = kmode.fit_predict(tmp)
# tmp['2clusters'] = clusters

# %%
# tmp[tmp['2clusters'] == 0]['high_category'].value_counts()

# %% [markdown]
# # 다시 돌아가자

# %%
print(train[train['category'].str.contains('nonfiction')][['rating', 'age']].describe()[:3])
print(train[train['category'].str.contains('biography')][['rating', 'age']].describe()[:3])
#biograpy는 nonfiction의 하위 범주에 속하는 것으로 아는데, 일단 보자.
# Out:
#             rating          age
# count  1679.000000  1192.000000
# mean      7.322216    32.393456
# std       2.552743    13.473626
#             rating          age
# count  7727.000000  5097.000000
# mean      7.248479    38.103590
# std       2.372368    12.128363

# %%
print(train[train['category'].str.contains('biography') & (train['category'] != 'biography autobiography')][['book_title', 'category']].sample(10))
# christian biography, fiction autobiography 이상한 놈들이 있다.
# Out:
#                                                book_title  \
# 274118                       Joni: An Unforgettable Story
# 34282          Peace Pilgrim Her Life and Work In Her Own
# 185754  One Step at a Time: The Remarkable True Story ...
# 291296  \Cher Ã©cran-- \": Journal personnel, ordinate...
# 265189  Bekenntnisse des Hochstaplers Felix Krull. Der...
# 125433                           Doris Day: Her own story
# 209680                Dave Gorman's Googlewhack Adventure
# 34284          Peace Pilgrim Her Life and Work In Her Own
# 305783  Footprints in the Sand: The Inspiring Life Beh...
# 239805            Bloomers Biros and Wellington Boots How
#
#                      category
# 274118    christian biography
# 34282               biography
# 185754    christian biography
# 291296          autobiography
# 265189  fiction autobiography
# 125433              biography
# 209680              biography
# 34284               biography
# 305783    christian biography
# 239805              biography

# %%
# 그냥 따로 묶자
# books['high_category'].where(books['category'].str.contains('biograpy')==False, 'biography', inplace=True)

# %%
(train[train['category'].str.contains('religion')].sample(10, replace=True))
#종교로 묶을 만한 녀석들. arab, budd, bible, hind, christian
# Out:
#         user_id        isbn  rating   age            city           state  \
# 281952   266512  1573926809       7  34.0         orlando         florida
# 186082   224745  0252006860       6  66.0        portland          oregon
# 137201    67547  1569754098       7  42.0     sierramadre      california
# 124336    16795  0884194051       6  47.0  mechanicsville        maryland
# 231664   179734  0781434726       3  26.0      greenville   southcarolina
# 168960    76499  0802807348      10   NaN         newyork         newyork
# 306404   273858  0937064343       3   NaN      losangeles      california
# 256909    74801  0877286183       7   NaN          astarx  myinfinitemind
# 123078    62546  0684849739       4  30.0       nashville       tennessee
# 9728     197659  1562921533       8  49.0         indiana    pennsylvania
#
#          country                                         book_title  \
# 281952       usa  Looking for a Miracle: Weeping Icons, Relics, ...
# 186082       usa              Their eyes were watching God: A novel
# 137201       usa  Just Add Buddha: Quick Buddhist Solutions to H...
# 124336       usa          101 Promises Worth Keeping (For Men Only)
# 231664       usa  When Your Marriage Needs Repair: A No-Nonsense...
# 168960       usa                              The Politics of Jesus
# 306404       usa  Spiritual Messages From a Buffalo Rider: A Man...
# 256909  universe                                              Bahir
# 123078       usa                                     The BIBLE CODE
# 9728         usa                          God's Treasury of Virtues
#
#                   book_author  year_of_publication  \
# 281952            Joe Nickell               1999.0
# 186082     Zora Neale Hurston               1978.0
# 137201          Franz Metcalf               2004.0
# 124336           Neil Eskelin               1995.0
# 231664  David B., Dr. Hawkins               2001.0
# 168960      John Howard Yoder               1994.0
# 306404           Hua-Ching Ni               1990.0
# 256909           Aryeh Kaplan               1989.0
# 123078        Michael Drosnin               1998.0
# 9728              Honor Books               1995.0
#
#                                   publisher language  category  \
# 281952                     Prometheus Books       en  religion
# 186082         University of Illinois Press       en  religion
# 137201                        Ulysses Press       en  religion
# 124336                       Charisma House       en  religion
# 231664                         Victor Books       en  religion
# 168960   Wm. B. Eerdmans Publishing Company       en  religion
# 306404  Shrine of the Eternal Breath of Tao       en  religion
# 256909                         Weiser Books       en  religion
# 123078                           Touchstone       en  religion
# 9728                     Chariot Victor Pub       en  religion
#
#                                                   summary
# 281952                                 No Marketing Blurb
# 186082  When Janie Starks returns home, the small blac...
# 137201  Written for spiritual seekers who deal with un...
# 124336  Inspirational speaker Neil Eskelin identifies ...
# 231664  Perhaps your relationship has been withered by...
# 168960       This second edition is updated and expanded.
# 306404  This collection of lectures and workshops was ...
# 256909  The first book in any language ever to reveal ...
# 123078  Argues that a hidden mathematical code embedde...
# 9728    Presents stories, quotations, poems, and hymns...

# %%
print(train[train['category'].str.contains('religion')][['rating', 'age']].describe()[:3])
print(train[train['category'].str.contains('christian')][['rating', 'age']].describe()[:3])
# Out:
#             rating          age
# count  2409.000000  1699.000000
# mean      7.399336    38.935256
# std       2.482483    12.084578
#            rating         age
# count  290.000000  207.000000
# mean     7.051724   35.690821
# std      2.835895   12.410889

# %%
lst = ['religion', 'christian', 'budd', 'arab', 'cath', 'bible', 'muslim', 'hind', 'church', 'pray', 'monk']
lst = '|'.join(lst)
print(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'religion', inplace=True)
# Out:
# religion|christian|budd|arab|cath|bible|muslim|hind|church|pray|monk

# %%
#종교를 처리했으니 다시 전기로
lst = ['biography']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'biography', inplace=True)

# %%
books['high_category'].value_counts()
# Out:
# 1                                         68851
# fiction                                   33016
# juvenile                                   7317
# biography                                  3351
# religion                                   2151
#                                           ...
# gone with the wind motion picture 1939        1
# disguise                                      1
# country lawyers                               1
# humorous stories brazilian                    1
# alternative histories                         1
# Name: high_category, Length: 4016, dtype: int64

# %%
print(train[train['category'].str.contains('humor')][['rating', 'age']].describe()[:3])
print(train[train['category'].str.contains('wit')][['rating', 'age']].describe()[:3])
# Out:
#             rating          age
# count  3378.000000  2405.000000
# mean      7.330373    36.172973
# std       2.358667    11.567426
#            rating         age
# count  187.000000  141.000000
# mean     6.780749   36.269504
# std      2.596535   11.757599

# %%
train[train['category'].str.contains('wit')].sample(10)
# Out:
#         user_id        isbn  rating   age             city  \
# 254074    79441  0805009329       8  43.0      sprucegrove
# 127418   164675  0871135809       7  55.0         portland
# 211204    71940  3492045170       7   NaN           berlin
# 211213   230632  3492045170       8  35.0             bonn
# 211209   164340  3492045170       1   NaN  frankfurtammain
# 214946   264321  0030448514       3  33.0          toronto
# 211199   204825  3492045170       8  18.0      burladingen
# 127419   169735  0871135809       8   NaN           nisswa
# 285500   138132  0435120956       9  27.0       wellington
# 254723   225610  0750917164       8  28.0          oakland
#
#                      state     country  \
# 254074             alberta      canada
# 127418              oregon         usa
# 211204              berlin     germany
# 211213  nordrheinwestfalen     germany
# 211209              hessen     germany
# 214946             ontario      canada
# 211199   badenwuerttemberg     germany
# 127419           minnesota         usa
# 285500                 NaN  newzealand
# 254723          california         usa
#
#                                                book_title     book_author  \
# 254074                           We're Eating More Beets!    G.B. Trudeau
# 127418  All the Trouble in the World: The Lighter Side...   P.J. O'Rourke
# 211204  Stupid White Men. Eine Abrechnung mit dem Amer...   Michael Moore
# 211213  Stupid White Men. Eine Abrechnung mit dem Amer...   Michael Moore
# 211209  Stupid White Men. Eine Abrechnung mit dem Amer...   Michael Moore
# 214946                         Doonesbury's greatest hits    G. B Trudeau
# 211199  Stupid White Men. Eine Abrechnung mit dem Amer...   Michael Moore
# 127419  All the Trouble in the World: The Lighter Side...   P.J. O'Rourke
# 285500     New Windmills: Of Mice and Men (New Windmills)  John Steinbeck
# 254723    1066 & All That: A Memorable History of England    W. C. Sellar
#
#         year_of_publication                                         publisher  \
# 254074               1988.0                                   Henry Holt & Co
# 127418               1994.0                                    Pub Group West
# 211204               2003.0                                             Piper
# 211213               2003.0                                             Piper
# 211209               2003.0                                             Piper
# 214946               1978.0                        Holt, Rinehart and Winston
# 211199               2003.0                                             Piper
# 127419               1994.0                                    Pub Group West
# 285500               1965.0  Heinemann Educational Books - Secondary Division
# 254723               1997.0                                 Natl Book Network
#
#        language                          category  \
# 254074       en            american wit and humor
# 127418       en            american wit and humor
# 211204       de            american wit and humor
# 211213       de            american wit and humor
# 211209       de            american wit and humor
# 214946       en  american wit and humor pictorial
# 211199       de            american wit and humor
# 127419       en            american wit and humor
# 285500       en   people with mental disabilities
# 254723       en             english wit and humor
#
#                                                   summary
# 254074  The creator of &quot;Doonesbury&quot; casts an...
# 127418  Offers a satirical view of the world&#39;s wor...
# 211204  Bissige Satire und Abrechnung mit der Politik ...
# 211213  Bissige Satire und Abrechnung mit der Politik ...
# 211209  Bissige Satire und Abrechnung mit der Politik ...
# 214946  A collection of &quot;Doonesbury&quot; comic s...
# 211199  Bissige Satire und Abrechnung mit der Politik ...
# 127419  Offers a satirical view of the world&#39;s wor...
# 285500  Novel-Ties study guides contain reproducible p...
# 254723  Illustrated with contemporary pictures includi...

# %%
#전기 후엔 유머
lst = ['humor', 'fun', 'wit ']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'humor', inplace=True)

# %%
(train[train['category'].str.contains('body') \
	& (train['category'] != 'body mind spirit') \
	])\
	# .sample()
# Out:
#         user_id        isbn  rating   age           city               state  \
# 159259    35859  0803720408       8   NaN         duluth           minnesota
# 195418   141210  3548363938       6   NaN        tbingen     badenwrttemberg
# 195419   180571  3548363938       6  52.0      bielefeld  nordrheinwestfalen
# 202632   188010  0445205318       5   NaN       edmonton             alberta
# 202633    95930  0445205318       7   NaN         bethel         connecticut
# 209710    93147  0752208861       7  31.0          leeds             england
# 216803   179826  1857236262       9  22.0         oldham             england
# 217164   222296  1580050158       1   NaN     chapelhill       northcarolina
# 217165     5582  1580050158      10  26.0        seattle          washington
# 217166   100906  1580050158       2  34.0        seattle          washington
# 217167   150663  1580050158      10  24.0       nightsky              oregon
# 217168   184789  1580050158      10  34.0      vancouver     britishcolumbia
# 217169   271144  1580050158       7  25.0    albuquerque           newmexico
# 217170   259517  1580050158       9  23.0     schaumburg            illinois
# 217171   182306  1580050158       9   NaN    minneapolis           minnesota
# 228431   185233  0590679872       2  31.0     winnemucca              nevada
# 228432   113955  0590679872       8  16.0        webster            missouri
# 228433    62239  0590679872       6   9.0       yarmouth          novascotia
# 228664   185233  0395264626       2  31.0     winnemucca              nevada
# 230565   141491  0895297698       7  47.0    westminster     britishcolumbia
# 238446   140255  0440441900       6  21.0        orlando             florida
# 249134   196502  0911226184       5  38.0        decatur             georgia
# 262750    31838  0394747461       8  42.0  sanbernardino          california
# 274353   100782  0751519391       4  30.0         london             england
# 277864   174062  1856976629       9  38.0    kelseyville          california
# 278982   248289  1851701834       7  29.0       brighton             england
# 282392     4271  0002258579       5   NaN        bergamo           lombardia
# 282393   218360  0002258579       7  32.0      edinburgh            scotland
# 282658   232579  0060909676       7  38.0        chicago            illinois
# 298470    68265  0881623717      10  42.0       ryebrook             newyork
# 301781   103542  0803720416       6  47.0        stanley               idaho
# 304418   176619  1563052989       5  29.0     millington           newjersey
# 304803   189190  0671444816       8  28.0   winstonsalem       northcarolina
#
#               country                                         book_title  \
# 159259            usa                                              Parts
# 195418        germany  Der tote Fisch in der Hand und andere Geheimni...
# 195419        germany  Der tote Fisch in der Hand und andere Geheimni...
# 202632         canada                                            Catspaw
# 202633            usa                                            Catspaw
# 209710  unitedkingdom                                    Solitaire for 2
# 216803  unitedkingdom                                         Inversions
# 217164            usa   Cunt: A Declaration of Independence (Live Girls)
# 217165            usa   Cunt: A Declaration of Independence (Live Girls)
# 217166            usa   Cunt: A Declaration of Independence (Live Girls)
# 217167            usa   Cunt: A Declaration of Independence (Live Girls)
# 217168         canada   Cunt: A Declaration of Independence (Live Girls)
# 217169            usa   Cunt: A Declaration of Independence (Live Girls)
# 217170            usa   Cunt: A Declaration of Independence (Live Girls)
# 217171            usa   Cunt: A Declaration of Independence (Live Girls)
# 228431            usa        Help!: I'm Trapped in My Gym Teacher's Body
# 228432            usa        Help!: I'm Trapped in My Gym Teacher's Body
# 228433         canada        Help!: I'm Trapped in My Gym Teacher's Body
# 228664            usa                          Herbert Hated Being Small
# 230565            usa                    The Real Vitamin & Mineral Book
# 238446            usa                          I Was a 98-Pound Duckling
# 249134            usa   Frogs into Princes: Neuro Linguistic Programming
# 262750            usa                               The body in question
# 274353  unitedkingdom                              The Inward Revolution
# 277864            usa  I Wonder Why I Blink: And Other Questions Abou...
# 278982  unitedkingdom                         Encyclopedia of the Occult
# 282392          italy                                  Resurrection Club
# 282393  unitedkingdom                                  Resurrection Club
# 282658            usa  The Obsession : Reflections on the Tyranny of ...
# 298470            usa                    Eye to Eye: How People Interact
# 301781            usa                                              Parts
# 304418            usa                                      The Body Book
# 304803            usa                                    IDENTITY MATRIX
#
#                   book_author  year_of_publication                 publisher  \
# 159259            Tedd Arnold               1997.0                Dial Books
# 195418            Allan Pease               2003.0               Ullstein Tb
# 195419            Allan Pease               2003.0               Ullstein Tb
# 202632          Joan D. Vinge               1989.0              Warner Books
# 202633          Joan D. Vinge               1989.0              Warner Books
# 209710         Neil Mullarkey               1995.0             Pan Macmillan
# 216803          Iain M. Banks               1998.0            Orbit Book Co.
# 217164            Inga Muscio               1998.0           Seal Press (WA)
# 217165            Inga Muscio               1998.0           Seal Press (WA)
# 217166            Inga Muscio               1998.0           Seal Press (WA)
# 217167            Inga Muscio               1998.0           Seal Press (WA)
# 217168            Inga Muscio               1998.0           Seal Press (WA)
# 217169            Inga Muscio               1998.0           Seal Press (WA)
# 217170            Inga Muscio               1998.0           Seal Press (WA)
# 217171            Inga Muscio               1998.0           Seal Press (WA)
# 228431          Todd Strasser               1997.0        Apple (Scholastic)
# 228432          Todd Strasser               1997.0        Apple (Scholastic)
# 228433          Todd Strasser               1997.0        Apple (Scholastic)
# 228664           Karla Kuskin               1979.0   Houghton Mifflin Co (J)
# 230565  Shari Lieberman Ph.D.               1997.0    Avery Publishing Group
# 238446       Jean Van Leeuwen               1987.0              Bantam Books
# 249134        Richard Bandler               1979.0         Nlp Comprehensive
# 262750        Jonathan Miller               1982.0             Vintage Books
# 274353       Deborah Benstead               1998.0     Firebird Distributing
# 277864          Brigid Avison               1997.0                Kingfisher
# 278982           Lewis Spence               1994.0             Bracken Books
# 282392    Christopher Wallace               1999.0          Harpercollins Uk
# 282393    Christopher Wallace               1999.0          Harpercollins Uk
# 282658            Kim Chernin               1982.0  HarperCollins Publishers
# 298470         Peter E. Marsh               1991.0                Book Sales
# 301781            Tedd Arnold               1997.0                Dial Books
# 304418     Sara Bonnett Stein               1992.0            Workman Pub Co
# 304803          Kelli M. Gary               1982.0                    Pocket
#
#        language              category  \
# 159259       en            human body
# 195418       de         body language
# 195419       de         body language
# 202632       en            bodyguards
# 202633       en            bodyguards
# 209710       en         body language
# 216803       en            bodyguards
# 217164       en   body image in women
# 217165       en   body image in women
# 217166       en   body image in women
# 217167       en   body image in women
# 217168       en   body image in women
# 217169       en   body image in women
# 217170       en   body image in women
# 217171       en   body image in women
# 228431       en          bodybuilding
# 228432       en          bodybuilding
# 228433       en          bodybuilding
# 228664       en             body size
# 230565       en  minerals in the body
# 238446       en   body image in girls
# 249134       en         body language
# 262750       en            body human
# 274353       en         mind and body
# 277864       en            body human
# 278982       en            human body
# 282392       en        body snatching
# 282393       en        body snatching
# 282658       en            body image
# 298470       en         body language
# 301781       en            human body
# 304418       en            body human
# 304803       en        body snatching
#
#                                                   summary
# 159259  A five-year-old boy thinks his body is falling...
# 195418  Die Einführung in die Körpersprache zeigt auf,...
# 195419  Die Einführung in die Körpersprache zeigt auf,...
# 202632       CAT: Street Punk, Psion, Telepath, Survivor.
# 202633       CAT: Street Punk, Psion, Telepath, Survivor.
# 209710  A novelization of the film of the same name, s...
# 216803  Iain M. Banks&#39; previous science fiction no...
# 217164  This provocative analysis of women&#39;s relat...
# 217165  This provocative analysis of women&#39;s relat...
# 217166  This provocative analysis of women&#39;s relat...
# 217167  This provocative analysis of women&#39;s relat...
# 217168  This provocative analysis of women&#39;s relat...
# 217169  This provocative analysis of women&#39;s relat...
# 217170  This provocative analysis of women&#39;s relat...
# 217171  This provocative analysis of women&#39;s relat...
# 228431  After an accident causes Jake Sherman to switc...
# 228432  After an accident causes Jake Sherman to switc...
# 228433  After an accident causes Jake Sherman to switc...
# 228664  Short Herbert and tall Philomel discover that ...
# 230565  This updated and expanded edition is an all-in...
# 238446  A thirteen-year-old who suffers from several &...
# 249134  &quot;NLP is an explicit and powerful model of...
# 262750                        Medizingeschichte / Körper.
# 274353  Other steps in this practical guide, such as m...
# 277864  In a question and answer format addresses basi...
# 278982  A delight for devotees of the weird and the st...
# 282392  Mediocre PR consultant Charles Kidd might just...
# 282393  Mediocre PR consultant Charles Kidd might just...
# 282658  &quot;The obsession is a deeply committed and ...
# 298470  Human communications are fully explored in a s...
# 301781  A five-year-old boy thinks his body is falling...
# 304418  Facts and explanations about the various body ...
# 304803  &quot;Like many of Jack Chalker&#39;s earlier ...

# %%
#전기 후엔 유머
lst = ['spirit']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'meditation', inplace=True)

# %%
(train[train['category'].str.contains('soci') \
	& (train['category'] != 'social science') \
	])\
	.sample(10)
# Out:
#         user_id        isbn  rating   age               city      state  \
# 260958    89207  3453022548       7  26.0          gateshead    england
# 247761   210822  0534205208       6  36.0         neworleans  louisiana
# 28640     18861  0802132952       1  45.0            orlando    florida
# 288448   269916  013040456X       7  28.0  chudleighknighton    england
# 293679   162690  0749933011       1  33.0          cleveland       ohio
# 304619   182837  0380774429       6  26.0         burlington    vermont
# 283181    64185  0439087309       7  20.0            hammond  louisiana
# 119796   135376  067187120X       9   NaN           lasvegas     nevada
# 288452   269916  0333719344       8  28.0  chudleighknighton    england
# 238840   180860  0671637800       1   NaN             london    england
#
#               country                                         book_title  \
# 260958  unitedkingdom                                 Das Tal Der Pferde
# 247761            usa      Social Policy: From Theory to Policy Practice
# 28640             usa                                        Naked Lunch
# 288448  unitedkingdom  Research Methods for Social Science: A Practic...
# 293679            usa                                           Love Bug
# 304619            usa                     All the Good Men Are Not Taken
# 283181            usa                         10 Things I Hate About You
# 119796            usa                                  SEE I TOLD YOU SO
# 288452  unitedkingdom  Social work ethics: Politics, principles and p...
# 238840  unitedkingdom                                A KINGDOM OF DREAMS
#
#                   book_author  year_of_publication  \
# 260958              Jean Auel               2002.0
# 247761       Bruce S. Jansson               1994.0
# 28640    William S. Burroughs               1992.0
# 288448          R. A. McQueen               2002.0
# 293679             Zoe Barnes               2002.0
# 304619           Lisa Simmons               1996.0
# 283181         David Levithan               1999.0
# 119796  Rush H., III Limbaugh               1993.0
# 288452          Chris L Clark               2000.0
# 238840        Judith McNaught               1989.0
#
#                              publisher language                      category  \
# 260958                     Distribooks       de           primitive societies
# 247761  Brooks/Cole Publishing Company       en                social service
# 28640                      Grove Press       en  alienation social psychology
# 288448    Longman Group United Kingdom       en               social sciences
# 293679                   Piatkus Books       en         dating social customs
# 304619             Sterling Pub Co Inc       en         dating social customs
# 283181                      Scholastic       en         dating social customs
# 119796                       Zondervan       en               social problems
# 288452                 Macmillan Press       en                social service
# 238840                          Pocket       en      aristocracy social class
#
#                                                   summary
# 260958  - Ayla, als Andere vom Clan des Bären (Neander...
# 247761  This book has been completely reorganized to f...
# 28640   Bill Lee, an addict-hustler, travels to Mexico...
# 288448  Written in a clear, accessible and lively styl...
# 293679  Don&#39;t get bitten...If love is a bug then L...
# 304619  Reveals how to find the ideal companion, with ...
# 283181  Told she can&#39;t date until her older sister...
# 119796  The controversial conservative radio personali...
# 288452  This book offers a critical introduction to pr...
# 238840  A Kingdom Of Dreams is the tender, tempestuous...

# %%
# 사회 관련은 social로 퉁치자
lst = ['soci', 'discrimination']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'social', inplace=True)

# %%
(train[train['category'].str.contains('young') \
	& (train['category'] != 'fiction') \
	# & (train['category'] != 'political science') \
	# & (train['category'].str.contains('adventure') == True) \
	& (train['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#         user_id        isbn  rating   age              city          state  \
# 47896     11676  0380732289      10   NaN               NaN            NaN
# 47897    125774  0380732289       8  36.0            tehran         tehran
# 47898    228351  0380732289       8  16.0        charleston  southcarolina
# 47899    200674  0380732289       8  58.0         pittsburg       missouri
# 47900     88847  0380732289      10  17.0            elpaso          texas
# ...         ...         ...     ...   ...               ...            ...
# 295105   196277  0316605107       9  15.0           lincoln       nebraska
# 296329    73746  0743436849       2  16.0       watkinsglen        newyork
# 300014   249415  0380814439       7  15.0        mamaroneck        newyork
# 302759   247245  0060280786       9   NaN         kennewick     washington
# 306757   276647  0689822294      10  13.0  arlingtonheights       illinois
#
#        country                                       book_title  \
# 47896      NaN                                 The China Garden
# 47897     iran                                 The China Garden
# 47898      usa                                 The China Garden
# 47899      usa                                 The China Garden
# 47900      usa                                 The China Garden
# ...        ...                                              ...
# 295105     usa     A Living Nightmare (Cirque du Freak, Book 1)
# 296329     usa                          The Queen of Everything
# 300014     usa                                   Truth or Dairy
# 302759     usa                                Monster (Amistad)
# 306757     usa  Heaven (Coretta Scott King Author Award Winner)
#
#               book_author  year_of_publication  \
# 47896           Liz Berry               1999.0
# 47897           Liz Berry               1999.0
# 47898           Liz Berry               1999.0
# 47899           Liz Berry               1999.0
# 47900           Liz Berry               1999.0
# ...                   ...                  ...
# 295105        Darren Shan               2002.0
# 296329        Deb Caletti               2002.0
# 300014    Catherine Clark               2000.0
# 302759  Walter Dean Myers               1999.0
# 306757     Angela Johnson               1998.0
#
#                                      publisher language             category  \
# 47896                            HarperTempest       en  young adult fiction
# 47897                            HarperTempest       en  young adult fiction
# 47898                            HarperTempest       en  young adult fiction
# 47899                            HarperTempest       en  young adult fiction
# 47900                            HarperTempest       en  young adult fiction
# ...                                        ...      ...                  ...
# 295105                           Little, Brown       en  young adult fiction
# 296329                             Simon Pulse       en  young adult fiction
# 300014                           HarperTempest       en  young adult fiction
# 302759                                 Amistad       en  young adult fiction
# 306757  Simon & Schuster Children's Publishing       en  young adult fiction
#
#                                                   summary
# 47896   Clare also feels compelled to take midnight wa...
# 47897   Clare also feels compelled to take midnight wa...
# 47898   Clare also feels compelled to take midnight wa...
# 47899   Clare also feels compelled to take midnight wa...
# 47900   Clare also feels compelled to take midnight wa...
# ...                                                   ...
# 295105  As if by destiny, Darren is pulled to Mr. Crep...
# 296329  People ask me all the time what having Vince M...
# 300014  She&#39;s humiliated, she&#39;s angry....and s...
# 302759  This compelling novel is Walter Dean Myers&#39...
# 306757  You never know what&#39;s gonna come down -- i...
#
# [114 rows x 14 columns]

# %%
# 소설 처리
lst = ['fiction']
lst = '|'.join(lst)
books['high_category'].where(books['high_category'].str.contains(lst)==False, 'fiction', inplace=True)

# %%
# science잡기이전, 정책 관련은 policy로 
lst = ['policy', 'polit']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'politic', inplace=True)

# %%
(books[books['high_category'].str.contains('comput') \
	& (books['high_category'] != 'computers') \
	# & (books['category'] != 'political science') \
	# & (books['category'].str.contains('adventure') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	.sample(10)
# Out:
#               isbn                                         book_title  \
# 69716   0201781298  Java Software Solutions: Foundations of Progra...
# 49823   0452284392  Linked: How Everything Is Connected to Everyth...
# 144122  0201357445         Data Structures & Other Objects Using Java
# 89227   0517882213                     Big Blues: The Unmaking of IBM
# 62660   0072127066                       C/C++ Programmer's Reference
# 79956   0070050767  Client/Server Architecture (J. Ranade Series o...
# 134328  1562763482                            How to Use the Internet
# 86974   0072127732                            Linux (Hacking Exposed)
# 125874  187805886X                       Word for Windows for Dummies
# 144522  0970084226                       Memoirs of A Hi-Tech Hustler
#
#                    book_author  year_of_publication  \
# 69716               John Lewis               2002.0
# 49823   Albert-Laszlo Barabasi               2003.0
# 144122                 M. Main               1998.0
# 89227             Paul Carroll               1994.0
# 62660          Herbert Schildt               2000.0
# 79956              Alex Berson               1992.0
# 134328        Marietta Tretter               1995.0
# 86974              Brian Hatch               2001.0
# 125874              Dan Gookin               1993.0
# 144522         Gregory D. Evan               2001.0
#
#                                 publisher language  \
# 69716   Addison Wesley Publishing Company       en
# 49823                         Plume Books       en
# 144122             Addison Wesley Longman       en
# 89227             Three Rivers Press (CA)       en
# 62660           McGraw-Hill Osborne Media       en
# 79956                         McGraw Hill       en
# 134328             Macmillan Computer Pub       en
# 86974           McGraw-Hill Osborne Media       en
# 125874                        For Dummies       en
# 144522  Global Communications/Inner Light       en
#
#                                 category  \
# 69716     java computer program language
# 49823                  computer networks
# 144122  data structures computer science
# 89227                  computer industry
# 62660        c computer program language
# 79956            client server computing
# 134328                 computer networks
# 86974                  computer security
# 125874   microsoft windows computer file
# 144522                 computer security
#
#                                                   summary  \
# 69716   This best-selling text by Lewis and Loftus pro...
# 49823   In Linked, Barabási, a physicist whose work ha...
# 144122  In this book, author Michael Main takes a gent...
# 89227   Provides the inside story of the rise and fall...
# 62660   With this quick-access guide on hand, you&#39;...
# 79956   Describes in detail the much discussed but lit...
# 134328  This second edition expands on its proven full...
# 86974   This collection makes a unique contribution to...
# 125874  A lighthearted approach to Word for Windows co...
# 144522  What does AT&amp;T, MCI, Sprint, Page Net, Mob...
#
#                            high_category
# 69716     java computer program language
# 49823                  computer networks
# 144122  data structures computer science
# 89227                  computer industry
# 62660        c computer program language
# 79956            client server computing
# 134328                 computer networks
# 86974                  computer security
# 125874   microsoft windows computer file
# 144522                 computer security

# %%
# science잡기이전, 컴퓨터 관련은 computer로
lst = ['comput']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'computer', inplace=True)

# %%
(books[books['high_category'].str.contains('science') \
	& (books['high_category'] != 'science') \
	# & (books['category'] != 'political science') \
	# & (books['category'].str.contains('adventure') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 24687   9505500203                            Autoliberacion Interior
# 45273   0812519116       Enders Game (Ender Wiggins Saga (Paperback))
# 73549   0023728213                       Foundations of Earth Science
# 88081   0192815490        Crime and Punishment (The World's Classics)
# 97205   0870443461                                 Romance of the Sea
# 111685  0671240331                                      JOAN CRAWFORD
# 123044  0440002435                                     The art of war
# 123509  1861591004                                        The carrier
# 123790  1561569569  When Is It Great to Turn Green?  (An Environme...
# 124341  0297765558  Billion year spree: The history of science fic...
#
#                   book_author  year_of_publication  \
# 24687        Anthony de Mello               1987.0
# 45273        Orson Scott Card               1986.0
# 73549    Frederick K. Lutgens               1995.0
# 88081        Fedor Dostoevsky               1981.0
# 97205              J.H. Parry               1981.0
# 111685             Bob Thomas               1978.0
# 123044                Sun-tzu               1983.0
# 123509          Jamal Mahjoub               1998.0
# 123790  Michele Ingber Drohan               2001.0
# 124341    Brian Wilson Aldiss               1973.0
#
#                              publisher language                    category  \
# 24687   Magisterio del Rio de la Plata       es       freedom of conscience
# 45273                 St Martins Press       en    military art and science
# 73549                    Prentice Hall       en              earth sciences
# 88081          Oxford University Press       en    conscience in literature
# 97205                 Simon & Schuster       en       naval art and science
# 111685                Simon & Schuster       en  defensive military science
# 123044                 Delacorte Press       en    military art and science
# 123509                   Phoenix House       en      discoveries in science
# 123790                   Kidsbooks.Com       en      environmental sciences
# 124341         Weidenfeld and Nicolson       en      literature and science
#
#                                                   summary  \
# 24687   Este libro es un camino hacia la realización t...
# 45273   The Hugo and Nebula Award-winning classic is n...
# 73549   For courses in Earth Science. An abbreviated v...
# 88081   Raskolnikov, the first anti-hero, is literatur...
# 97205   National Geographic Society, from boats to shi...
# 111685  Yet in this definitive, powerful and dramatic ...
# 123044  These terse, aphoristic essays are unsurpassed...
# 123509  In Jutland a scientific instrument is discover...
# 123790  Presents information about various aspects of ...
# 124341  The novel was immediately successful, and the ...
#
#                      high_category
# 24687        freedom of conscience
# 45273     military art and science
# 73549               earth sciences
# 88081     conscience in literature
# 97205        naval art and science
# 111685  defensive military science
# 123044    military art and science
# 123509      discoveries in science
# 123790      environmental sciences
# 124341      literature and science

# %%
# 치환 코드. science잡기
lst = ['science']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'science', inplace=True)

# %%
# 두 범주 간 차이를 보기 위한 코드
print(train[train['category'].str.contains('humor')][['rating', 'age']].describe()[:3])
print(train[train['category'].str.contains('wit')][['rating', 'age']].describe()[:3])
# Out:
#             rating          age
# count  3378.000000  2405.000000
# mean      7.330373    36.172973
# std       2.358667    11.567426
#            rating         age
# count  187.000000  141.000000
# mean     6.780749   36.269504
# std      2.596535   11.757599

# %%
# 내용물을 들여다 보는 코드
(books[books['high_category'].str.contains('econom') \
	& (books['high_category'] != 'business economics') \
	& (books['high_category'] != 'business') \
	# & (books['category'].str.contains('men') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 18563   0140127089                                 The green consumer
# 30838   1576751996              Affluenza: The All-Consuming Epidemic
# 50742   2020042592                                 La ConvivialitÃ?Â©
# 50884   0688052606  Leaving the Nest: The Complete Guide to Living...
# 54283   0812928598  Starting and Running a Profitable Investment Club
# 56674   0394510240        Never done: A history of American housework
# 64330   0895772760                     Household Hints and Handy Tips
# 68046   0226025934                                The Human Condition
# 71095   0399518118               Heloise: Household Hints for Singles
# 71118   0743467795                                           Meltdown
# 76922   1558703616  Confessions of an Organized Homemaker: The Sec...
# 109157  4004304652  Gendai shakai no riron: Johoka, shohika shakai...
# 112662  0380581493                               Window over the Sink
# 113635  0028610903  The Complete Idiot's Guide to Organizing Your ...
# 117148  0003277585                                Economics Explained
# 119331  0517582112  Unlimited Wealth: The Theory and Practice of E...
# 120664  0333582632  Seeds of Change: Five Plants That Transformed ...
# 120854  2842055373          EnquÃ?Âªte au cÃ?Â?ur des multinationales
# 121390  0890817065                               More Hours in My Day
# 126506  0130189758               Macroeconomics: Principles and Tools
# 138363  0030897432                                    Basic economics
# 138374  039395403X                  Microeconomics, Selected Readings
# 138668  9684271980  PolÃ­tica econÃ³mica de MÃ©xico, 1982-1995: Lo...
# 139896  0812910168                           Family Circle Hints Book
# 148910  0091830923  From Bedlam To Bliss: the Complete Home Organi...
# 149291  0004703723                     Dictionary Of Economics-2Nd Ed
# 149292  0140136908    History of Economic Thought (Penguin Economics)
#
#                    book_author  year_of_publication  \
# 18563           John Elkington               1990.0
# 30838            John De Graaf               2002.0
# 50742              Ivan Illich               2003.0
# 50884        Dorinne Armstrong               1986.0
# 54283           Thomas E Ohara               1994.0
# 56674           Susan Strasser               1982.0
# 64330          Reader's Digest               1988.0
# 68046            Hannah Arendt               1958.0
# 71095                  Heloise               1993.0
# 71118          David Schofield               2003.0
# 76922        Deniece Schofield               1994.0
# 109157           Munesuke Mita               1996.0
# 112662             Peg Bracken               1982.0
# 113635       Georgene Lockwood               1997.0
# 117148           Peter Maunder               2000.0
# 119331        Paul Zane Pilzer               1991.0
# 120664             Hobhouse S.               1993.0
# 120854                   Attac               2001.0
# 121390           Emilie Barnes               1989.0
# 126506       Arthur O'Sullivan               2000.0
# 138363           Edwin G Dolan               1977.0
# 138374         Edwin Mansfield               1985.0
# 138668  Arturo OrtÃ­z Wadgymar               1995.0
# 139896           Erika Douglas               1986.0
# 148910            Wendy Shiels               1996.0
# 149291        Christopher Pass               1991.0
# 149292       William J. Barber               1992.0
#
#                                 publisher language  \
# 18563                       Penguin Books       en
# 30838          Berrett-Koehler Publishers       en
# 50742                               Seuil       fr
# 50884                       Harpercollins       en
# 54283                  Random House~trade       en
# 56674                      Pantheon Books       en
# 64330                    Putnam Pub Group       en
# 68046                  Univ of Chicago Pr       en
# 71095                       Perigee Books       en
# 71118   Simon & Schuster (Trade Division)       en
# 76922                     Betterway Books       en
# 109157                     Iwanami Shoten       ja
# 112662                         Avon Books       en
# 113635                        Alpha Books       en
# 117148                Collins Educational       en
# 119331                   Crown Publishers       en
# 120664               McClelland & Stewart       en
# 120854                         1001 nuits       fr
# 121390           Harvest House Publishers       en
# 126506                      Prentice Hall       en
# 138363                       Dryden Press       en
# 138374                W W Norton & Co Inc       en
# 138668           Editorial Nuestro Tiempo       es
# 139896             Random House Value Pub       en
# 148910             Random House Australia       en
# 149291                   Trafalgar Square       en
# 149292                        Penguin USA       en
#
#                           category  \
# 18563        consumption economics
# 30838        consumption economics
# 50742         economic development
# 50884               home economics
# 54283   business and economics etc
# 56674               home economics
# 64330               home economics
# 68046                    economics
# 71095               home economics
# 71118                   economists
# 76922               home economics
# 109157       consumption economics
# 112662              home economics
# 113635              home economics
# 117148                   economics
# 119331                   economics
# 120664             botany economic
# 120854                   economics
# 121390              home economics
# 126506              macroeconomics
# 138363                   economics
# 138374              microeconomics
# 138668      economic stabilization
# 139896              home economics
# 148910              home economics
# 149291                   economics
# 149292                   economics
#
#                                                   summary  \
# 18563   It&#39;s a deadly mistake to think that consum...
# 30838   Writings on the consequences of the pursuit of...
# 50742   Ivan Illich amplifie et radicalise sa critique...
# 50884   This guide for young adults, newlyweds, and si...
# 54283                                           Movement.
# 56674   &quot;Never Done&quot; begins by describing th...
# 64330   More than four thousand practical household hi...
# 68046   Hannah Arendt&#39;s The Human Condition is a s...
# 71095   The popular newspaper columnist offers handy, ...
# 71118   Before doing this he cannot resist visiting To...
# 76922   Now Schofield&#39;s back, with a 90&#39;s vers...
# 109157  「ゆたかな社会」のダイナミズムと魅力の根拠とは何か。同時に、この社会の現在ある形が生み出す、...
# 112662  The popular columnist and best-selling author ...
# 113635  One of a series offering straightforward advic...
# 117148  Authoritative, yet accessible to all, the revi...
# 119331  In a refutation of conventional economic theor...
# 120664  Charts the history of man&#39;s need, or greed...
# 120854  Sur les cent premières entités économiques mon...
# 121390  Emilie&#39;s guidelines, charts, and checklist...
# 126506  The authors build a framework for economic rea...
# 138363  Our job now is not to disappoint them. They co...
# 138374  Broader and more varied in its coverage than o...
# 138668  &quot;Examination of the neoliberal policies u...
# 139896  Provides two thousand sensible reader-submitte...
# 148910  A practical guidebook on home management. Uses...
# 149291  This dictionary, now updated and revised, is a...
# 149292  The theories and methods of such men as Adam S...
#
#                      high_category
# 18563        consumption economics
# 30838        consumption economics
# 50742         economic development
# 50884               home economics
# 54283   business and economics etc
# 56674               home economics
# 64330               home economics
# 68046                    economics
# 71095               home economics
# 71118                   economists
# 76922               home economics
# 109157       consumption economics
# 112662              home economics
# 113635              home economics
# 117148                   economics
# 119331                   economics
# 120664             botany economic
# 120854                   economics
# 121390              home economics
# 126506              macroeconomics
# 138363                   economics
# 138374              microeconomics
# 138668      economic stabilization
# 139896              home economics
# 148910              home economics
# 149291                   economics
# 149292                   economics

# %%
# 치환 코드. business economics

#이전에 그놈의 비즈니스맨 잠깐만 처리해주자
lst = ['businessmen', 'businessmen']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'fiction', inplace=True)


lst = ['business', 'economi']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'economy', inplace=True)

# %%
# 내용물을 들여다 보는 코드
(books[books['high_category'].str.contains('family') \
	# & (books['high_category'] != 'family relationships') \
	& (books['high_category'] != 'business') \
	# & (books['category'].str.contains('men') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 522     0064470113                              Taking the Ferry Home
# 716     0395710901  Punished by Rewards: The Trouble With Gold Sta...
# 887     0688169678                      We Are Our Mothers' Daughters
# 1838    0679761837                          A Natural History of Love
# 2026    0894805770                      What to Expect the First Year
# ...            ...                                                ...
# 149215  0385299613          Secrets About Men Every Woman Should Know
# 149468  1888387408  Little Bits of Wisdom : A Collection of Tips a...
# 149477  0062737465  Healthy Child, Whole Child: Integrating the Be...
# 149490  074341702X  The Wonder of Girls : Understanding the Hidden...
# 149546  1576734218                              On Becoming Childwise
#
#                book_author  year_of_publication  \
# 522             Pam Conrad               1990.0
# 716             Alfie Kohn               1995.0
# 887          Cokie Roberts               2000.0
# 1838        Diane Ackerman               1995.0
# 2026      Arlene Eisenberg               1989.0
# ...                    ...                  ...
# 149215  Barbara De Angelis               1990.0
# 149468       Josie Bissett               2001.0
# 149477   Stuart H. Ditchek               2002.0
# 149490      Michael Gurian               2002.0
# 149546           Gary Ezzo               1999.0
#
#                                      publisher language              category  \
# 522               Harpercollins Juvenile Books       en       family problems
# 716                           Houghton Mifflin       en  family relationships
# 887                                  Perennial       en  family relationships
# 1838                         Vintage Books USA       en  family relationships
# 2026                        Workman Publishing       en  family relationships
# ...                                        ...      ...                   ...
# 149215                   Bantam Dell Pub Group       en  family relationships
# 149468  Compendium Publishing & Communications       en  family relationships
# 149477                          HarperResource       en  family relationships
# 149490                                   Atria       en  family relationships
# 149546                               Multnomah       en  family relationships
#
#                                                   summary  \
# 522     Two sixteen-year-old girls from different soci...
# 716     Criticizes the system of motivating through re...
# 887     The award-winning ABC-TV anchorwoman and NPR n...
# 1838    The author of the best-selling A Natural Histo...
# 2026    But how moms and dads care for their brand-new...
# ...                                                   ...
# 149215  Provides a practical guide for women on how to...
# 149468  Parents offer their suggestions on becoming a ...
# 149477  Filled with compassion, common sense, and the ...
# 149490  The author of The Wonder of Boys introduces a ...
# 149546  On Becoming Childwise responds to this need by...
#
#                high_category
# 522          family problems
# 716     family relationships
# 887     family relationships
# 1838    family relationships
# 2026    family relationships
# ...                      ...
# 149215  family relationships
# 149468  family relationships
# 149477  family relationships
# 149490  family relationships
# 149546  family relationships
#
# [988 rows x 9 columns]

# %%
# 치환 코드. family

#이전에 그놈의 비즈니스맨 잠깐만 처리해주자
lst = ['family']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'family', inplace=True)

# %%
# 내용물을 들여다 보는 코드
(books[books['high_category'].str.contains('help') \
	# & (books['high_category'] != 'family relationships') \
	& (books['high_category'] != 'self help') \
	# & (books['category'].str.contains('men') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 77451   081931191X  The Little Witch Sisters (Parents Magazine Rea...
# 109551  0962923001  Don't Tie Yourself Up in Nots: How to Untie Yo...
#
#                 book_author  year_of_publication               publisher  \
# 77451   Stephanie Calmenson               1989.0  Parents Magazine Press
# 109551     David P. Schloss               1991.0        David P. Schloss
#
#        language              category  \
# 77451        en           helpfulness
# 109551       en  self help techniques
#
#                                                   summary  \
# 77451   Plinka has a surprise for her sister Tinka whe...
# 109551  This motivational book shares with the reader ...
#
#                high_category
# 77451            helpfulness
# 109551  self help techniques

# %%
# 두 범주 간 차이를 보기 위한 코드. 명상이나 자기계발이나 또이 아니냐
print(train[train['category'].str.contains('spirit')][['rating', 'age']].describe()[:3])
print(train[train['category'].str.contains('self')][['rating', 'age']].describe()[:3])
# Out:
#             rating          age
# count  1761.000000  1315.000000
# mean      7.206133    36.320913
# std       2.569066    11.836101
#             rating         age
# count  1431.000000  975.000000
# mean      7.030049   38.125128
# std       2.547412   11.867541

# %%
# 치환 코드. self help to meditation

#이전에 그놈의 비즈니스맨 잠깐만 처리해주자
lst = ['self', 'help']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'meditation', inplace=True)

# %%
# 내용물을 들여다 보는 코드
(books[books['high_category'].str.contains('body') \
	& (books['high_category'] != 'health') \
	& (books['high_category'] != 'health fitness') \
	# & (books['category'].str.contains('men') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 7217    0002258579                                  Resurrection Club
# 8558    1580050158   Cunt: A Declaration of Independence (Live Girls)
# 34700   0590679872        Help!: I'm Trapped in My Gym Teacher's Body
# 49120   0394747461                               The body in question
# 53334   0803720408                                              Parts
# 68273   1857236262                                         Inversions
# 69969   0895297698                    The Real Vitamin & Mineral Book
# 75885   0881623717                    Eye to Eye: How People Interact
# 90392   0752208861                                    Solitaire for 2
# 92161   0445205318                                            Catspaw
# 92661   0959365877                          Questions Are the Answers
# 96120   0060909676  The Obsession : Reflections on the Tyranny of ...
# 96949   0751519391                              The Inward Revolution
# 98790   0803720416                                              Parts
# 99907   3548363938  Der tote Fisch in der Hand und andere Geheimni...
# 112346  0440441900                          I Was a 98-Pound Duckling
# 123489  1856976629  I Wonder Why I Blink: And Other Questions Abou...
# 124186  1563052989                                      The Body Book
# 126824  0395264626                          Herbert Hated Being Small
# 127995  0671444816                                    IDENTITY MATRIX
# 131303  0911226184   Frogs into Princes: Neuro Linguistic Programming
# 142361  0959365818                                      Talk Language
# 143505  1851701834                         Encyclopedia of the Occult
#
#                   book_author  year_of_publication                 publisher  \
# 7217      Christopher Wallace               1999.0          Harpercollins Uk
# 8558              Inga Muscio               1998.0           Seal Press (WA)
# 34700           Todd Strasser               1997.0        Apple (Scholastic)
# 49120         Jonathan Miller               1982.0             Vintage Books
# 53334             Tedd Arnold               1997.0                Dial Books
# 68273           Iain M. Banks               1998.0            Orbit Book Co.
# 69969   Shari Lieberman Ph.D.               1997.0    Avery Publishing Group
# 75885          Peter E. Marsh               1991.0                Book Sales
# 90392          Neil Mullarkey               1995.0             Pan Macmillan
# 92161           Joan D. Vinge               1989.0              Warner Books
# 92661             Allan Pease               1999.0       Pease International
# 96120             Kim Chernin               1982.0  HarperCollins Publishers
# 96949        Deborah Benstead               1998.0     Firebird Distributing
# 98790             Tedd Arnold               1997.0                Dial Books
# 99907             Allan Pease               2003.0               Ullstein Tb
# 112346       Jean Van Leeuwen               1987.0              Bantam Books
# 123489          Brigid Avison               1997.0                Kingfisher
# 124186     Sara Bonnett Stein               1992.0            Workman Pub Co
# 126824           Karla Kuskin               1979.0   Houghton Mifflin Co (J)
# 127995          Kelli M. Gary               1982.0                    Pocket
# 131303        Richard Bandler               1979.0         Nlp Comprehensive
# 142361            Allan Pease               2002.0                     Orion
# 143505           Lewis Spence               1994.0             Bracken Books
#
#        language              category  \
# 7217         en        body snatching
# 8558         en   body image in women
# 34700        en          bodybuilding
# 49120        en            body human
# 53334        en            human body
# 68273        en            bodyguards
# 69969        en  minerals in the body
# 75885        en         body language
# 90392        en         body language
# 92161        en            bodyguards
# 92661        en         body language
# 96120        en            body image
# 96949        en         mind and body
# 98790        en            human body
# 99907        de         body language
# 112346       en   body image in girls
# 123489       en            body human
# 124186       en            body human
# 126824       en             body size
# 127995       en        body snatching
# 131303       en         body language
# 142361       en         body language
# 143505       en            human body
#
#                                                   summary  \
# 7217    Mediocre PR consultant Charles Kidd might just...
# 8558    This provocative analysis of women&#39;s relat...
# 34700   After an accident causes Jake Sherman to switc...
# 49120                         Medizingeschichte / Körper.
# 53334   A five-year-old boy thinks his body is falling...
# 68273   Iain M. Banks&#39; previous science fiction no...
# 69969   This updated and expanded edition is an all-in...
# 75885   Human communications are fully explored in a s...
# 90392   A novelization of the film of the same name, s...
# 92161        CAT: Street Punk, Psion, Telepath, Survivor.
# 92661   Using simple, field-tested skills and and stra...
# 96120   &quot;The obsession is a deeply committed and ...
# 96949   Other steps in this practical guide, such as m...
# 98790   A five-year-old boy thinks his body is falling...
# 99907   Die Einführung in die Körpersprache zeigt auf,...
# 112346  A thirteen-year-old who suffers from several &...
# 123489  In a question and answer format addresses basi...
# 124186  Facts and explanations about the various body ...
# 126824  Short Herbert and tall Philomel discover that ...
# 127995  &quot;Like many of Jack Chalker&#39;s earlier ...
# 131303  &quot;NLP is an explicit and powerful model of...
# 142361  Sometimes people are so busy communicating tha...
# 143505  A delight for devotees of the weird and the st...
#
#                high_category
# 7217          body snatching
# 8558     body image in women
# 34700           bodybuilding
# 49120             body human
# 53334             human body
# 68273             bodyguards
# 69969   minerals in the body
# 75885          body language
# 90392          body language
# 92161             bodyguards
# 92661          body language
# 96120             body image
# 96949          mind and body
# 98790             human body
# 99907          body language
# 112346   body image in girls
# 123489            body human
# 124186            body human
# 126824             body size
# 127995        body snatching
# 131303         body language
# 142361         body language
# 143505            human body

# %%
# 치환 코드. health

#이전에 그놈의 비즈니스맨 잠깐만 처리해주자
lst = ['health', 'body']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'health', inplace=True)

# %%
# 내용물을 들여다 보는 코드 동물 좀 합치자 amphibian reptil mamma panda bear chick
(books[books['high_category'].str.contains('fly') \
	& (books['high_category'] != 'pets') \
	& (books['high_category'] != 'health fitness') \
	# & (books['category'].str.contains('men') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 16693   0060176539                        Breakthrough: The Next Step
# 40992   0832903507         Orvis Fly Fishing Guide (Nick Lyons Books)
# 45422   0671956019         Nancy Drew #58 - The Flying Saucer Mystery
# 68222   096525660X                      Fly Fishing the Sierra Nevada
# 82012   006100958X                        Breakthrough: The Next Step
# 87125   0806510609                   Flying Saucers--Serious Business
# 106118  0785320423                                      The UFO Files
# 107521  8401465516  100.000 Kilometros Tras Los Ovnis (Los Jet De ...
# 131012  0684816644  Open Skies, Closed Minds: Official Reactions t...
#
#               book_author  year_of_publication  \
# 16693    Whitley Strieber               1995.0
# 40992      Tom Rosenbauer               1984.0
# 45422       Carolyn Keene               1980.0
# 68222     Bill Sunderland               1999.0
# 82012    Whitley Strieber               1996.0
# 87125       Frank Edwards               1987.0
# 106118       Jerome Clark               1997.0
# 107521  Juan Jose Benitez               1997.0
# 131012          Nick Pope               1996.0
#
#                                  publisher language  \
# 16693             HarperCollins Publishers       en
# 40992                   New Win+publishing       en
# 45422                              Aladdin       en
# 68222                     Aguabonita Books       en
# 82012   Harper Mass Market Paperbacks (Mm)       en
# 87125                      Carol Pub Group       en
# 106118    Publications International, Ltd.       en
# 107521        Plaza & Janes Editores, S.A.       es
# 131012   Simon & Schuster (Trade Division)       en
#
#                            category  \
# 16693   unidentified flying objects
# 40992                   fly fishing
# 45422   unidentified flying objects
# 68222                   fly fishing
# 82012   unidentified flying objects
# 87125   unidentified flying objects
# 106118  unidentified flying objects
# 107521  unidentified flying objects
# 131012  unidentified flying objects
#
#                                                   summary  \
# 16693   Providing proof of the existence of extraterre...
# 40992   Now for the first time in full color, The Orvi...
# 45422   Nancy and her friends, in search of informatio...
# 68222   Describes when, where and how to fish Californ...
# 82012   Providing proof of the existence of extraterre...
# 87125   Presents a concise picture of the findings com...
# 106118  &quot;Tales of alien abductions, extraterrestr...
# 107521  J. J. Benítez, el famoso periodista y escritor...
# 131012  This text reveals what is in the X-Files resid...
#
#                       high_category
# 16693   unidentified flying objects
# 40992                   fly fishing
# 45422   unidentified flying objects
# 68222                   fly fishing
# 82012   unidentified flying objects
# 87125   unidentified flying objects
# 106118  unidentified flying objects
# 107521  unidentified flying objects
# 131012  unidentified flying objects

# %%
# 치환 코드. 갖은 동물...

lst = ['animal', 'pets', 'pet ', 'dog', 'cats', 'bird', 'insect', 'tiger', 'fish', 'amphibian', 'reptil', 'mamma', 'panda', 'bear', 'chick']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'animal', inplace=True)

# %%
# 내용물을 들여다 보는 코드 이제 자연
(books[books['high_category'].str.contains('natur') \
	& (books['high_category'] != 'nature') \
	& (books['high_category'] != 'health fitness') \
	# & (books['category'].str.contains('men') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 29310   092963408X  The Recycler's Handbook: Simple Things You Can Do
# 29927   0553348477                                           Ecotopia
# 42322   0195007778  A Sand County Almanac and Sketches Here and Th...
# 54145   0395445949                          Living at the end of time
# 55057   1567310052          Practical Encyclopedia of Natural Healing
# 59625   0061061603            The Rebellion (Dark Moon Legacy, Vol 3)
# 61277   0664325564         Winds in the woods: The story of John Muir
# 73667   0565091441  Nature's connections: An exploration of natura...
# 78013   089577321X  Great Disasters: Dramatic True Stories of Natu...
# 89596   3905514877                                     Broken Spirits
# 90702   1565072340  The 15-Minute Meal Planner/a Realistic Approac...
# 90926   0062510061    Flat Rock Journal: A Day in the Ozark Mountains
# 105459  0312044569  Journey into Summer (American Seasons, 2nd Sea...
# 118728  1559580917                   Encyclopedia of Natural Medicine
# 118993  1853066508                   Kent Stories of the Supernatrual
# 126998  0871916622                     Serendipity (Serendipity Book)
# 127646  184309066X      Vegitarian: The Best - Ever Recipe Collection
# 130914  0898152089              New Recipes from Moosewood Restaurant
# 131743  0916124525  Sharing the Joy of Nature: Nature Activities f...
# 136856  0061061514             The Seduction (Dark Moon Legacy No. 2)
# 146311  848428008X                 El interior del bosque (Literaria)
#
#                    book_author  year_of_publication  \
# 29310         EarthWorks Group               1990.0
# 29927        ERNEST CALLENBACH               1990.0
# 42322             Aldo Leopold               2000.0
# 54145     John Hanson Mitchell               1990.0
# 55057                 Bricklin               1997.0
# 59625            Cynthia Blair               1993.0
# 61277             John Stewart               1975.0
# 73667            Nicola McGirr               2000.0
# 78013          Reader's Digest               1989.0
# 89596          Eberhard Grames               1995.0
# 90702            Emilie Barnes               1995.0
# 90926                Ken Carey               1994.0
# 105459         Edwin Way Teale               1990.0
# 118728       Michael T. Murray               1991.0
# 118993         Johnnie Johnson               2000.0
# 126998        Stephen Cosgrove               1981.0
# 127646            Linda Fraser               2001.0
# 130914    Moosewood Collective               1987.0
# 131743          Joseph Cornell               1989.0
# 136856           Cynthia Blair               1993.0
# 146311  Eugenio Fuentes Pulido               1999.0
#
#                            publisher language  \
# 29310      Greenleaf Publishers (NY)       en
# 29927                         Bantam       en
# 42322        Oxford University Press       en
# 54145               Houghton Mifflin       en
# 55057                      MJF Books       en
# 59625   Harpercollins Juvenile Books       en
# 61277              Westminster Press       en
# 73667         Natural History Museum       en
# 78013               Putnam Pub Group       en
# 89596                Edition Stemmle       en
# 90702              Harvest House Pub       en
# 90926                  Harpercollins       en
# 105459                 St Martins Pr       en
# 118728              Prima Lifestyles       en
# 118993             Countryside Books       en
# 126998        Creative Education Inc       en
# 127646                  Hermes House       en
# 130914                  Ten Speed Pr       en
# 131743                    Dawn Pubns       en
# 136856  Harpercollins Juvenile Books       en
# 146311                Alba Editorial       es
#
#                                  category  \
# 29310   conservation of natural resources
# 29927   conservation of natural resources
# 42322                     natural history
# 54145                         naturalists
# 55057                         naturopathy
# 59625                        supernatural
# 61277                         naturalists
# 73667                     natural history
# 78013                   natural disasters
# 89596                  nature photography
# 90702               cookery natural foods
# 90926                     natural history
# 105459                    natural history
# 118728                        naturopathy
# 118993                       supernatural
# 126998  conservation of natural resources
# 127646              cooking natural foods
# 130914              cooking natural foods
# 131743                    natural history
# 136856                       supernatural
# 146311                      natural areas
#
#                                                   summary  \
# 29310   Explains what can be recycled, how to prepare,...
# 29927   Like a modern Gulliver, the skeptical Weston i...
# 42322   Nature writings of Aldo Leopold, one of the fo...
# 54145   In the best tradition of naturalist writing, a...
# 55057   From home remedies for poison ivy, toothaches ...
# 59625   Determined to fight his legacy of darkness and...
# 61277   A biography of the naturalist, geologist, inve...
# 73667   The text looks at the background of natural sc...
# 78013   A comprehensive, historical overview of some o...
# 89596   Broken Spirits is the second volume of still l...
# 90702   The 15-Minute Meal Planner offers a wealth of ...
# 90926   The author of Return of the Bird Tribes shares...
# 105459  Edwin Way Teale&#39;s account of his 19,000-mi...
# 118728  How to use herbs, vitamins, minerals, and diet...
# 118993  A collection of tales from Kent, including the...
# 126998  A large sea creature discovers she has importa...
# 127646                    Over 200 mouthwatering recipes.
# 130914  Two hundred recipes celebrating the varieties ...
# 131743  A treasury of games and activities for both ad...
# 136856  After Garth shares the secrets of his ancestry...
# 146311                                     Kriminalroman.
#
#                             high_category
# 29310   conservation of natural resources
# 29927   conservation of natural resources
# 42322                     natural history
# 54145                         naturalists
# 55057                         naturopathy
# 59625                        supernatural
# 61277                         naturalists
# 73667                     natural history
# 78013                   natural disasters
# 89596                  nature photography
# 90702               cookery natural foods
# 90926                     natural history
# 105459                    natural history
# 118728                        naturopathy
# 118993                       supernatural
# 126998  conservation of natural resources
# 127646              cooking natural foods
# 130914              cooking natural foods
# 131743                    natural history
# 136856                       supernatural
# 146311                      natural areas

# %%
# 치환 코드. 자연

lst = ['nature', 'environ', 'plant', 'earth']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'nature', inplace=True)

# %%
# 내용물을 들여다 보는 코드 이제 자연
(books[books['high_category'].str.contains('history') \
	& (books['high_category'] != 'history') \
	& (books['high_category'] != 'health fitness') \
	# & (books['category'].str.contains('men') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 21283   0571210708                        True Tales of American Life
# 42322   0195007778  A Sand County Almanac and Sketches Here and Th...
# 50689   0060922834  Modern Times: The World from the Twenties to t...
# 55195   0590493655  Everything You Need to Know About World Histor...
# 55912   0131337033                      Chronicle of the 20th Century
# 62387   0380708957                              Eyewitness to History
# 73667   0565091441  Nature's connections: An exploration of natura...
# 83784   1883013062      Time Eyewitness: 150 Years of Photojournalism
# 90926   0062510061    Flat Rock Journal: A Day in the Ozark Mountains
# 105275  0002551195                        A Day in the Life of Israel
# 105459  0312044569  Journey into Summer (American Seasons, 2nd Sea...
# 130965  0553210726                                  Federalist Papers
# 131743  0916124525  Sharing the Joy of Nature: Nature Activities f...
# 133767  0333685237  Mastering Modern World History (Palgrave Maste...
# 140026  0385177216  Forgotten News: The Crime of the Century and O...
# 140922  1893103056                            Abraham Lincoln's World
# 144251  091262700X     Framing of the Federal Constitution (Handbook)
# 148533  0812928431  People's Century, 20th: From the Dawn of the C...
#
#                    book_author  year_of_publication                publisher  \
# 21283              Paul Auster               2002.0      Faber and Faber Ltd
# 42322             Aldo Leopold               2000.0  Oxford University Press
# 50689             Paul Johnson               1992.0                Perennial
# 55195               Anne Zeman               1995.0               Scholastic
# 55912           Clifton Daniel               1987.0         Simon & Schuster
# 62387               John Carey               1990.0               Avon Books
# 73667            Nicola McGirr               2000.0   Natural History Museum
# 83784          Time-Life Books               1998.0          Time-Life Books
# 90926                Ken Carey               1994.0            Harpercollins
# 105275      David Elliot Cohen               1994.0            HarperCollins
# 105459         Edwin Way Teale               1990.0            St Martins Pr
# 130965      Alexander Hamilton               1982.0             Bantam Books
# 131743          Joseph Cornell               1989.0               Dawn Pubns
# 133767             Norman Lowe               1997.0       Palgrave Macmillan
# 140026             Jack Finney               1983.0          Doubleday Books
# 140922        Genevieve Foster               2000.0         Varsitybooks.Com
# 144251  Richard Brandon Morris               1986.0             Bernan Assoc
# 148533         Godfrey Hodgson               1998.0         Random House Inc
#
#        language                category  \
# 21283        en            oral history
# 42322        en         natural history
# 50689        en          history modern
# 55195        en           world history
# 55912        en          history modern
# 62387        en           world history
# 73667        en         natural history
# 83784        en          history modern
# 90926        en         natural history
# 105275       en            history asia
# 105459       en         natural history
# 130965       en  constitutional history
# 131743       en         natural history
# 133767       en          history modern
# 140026       en          history modern
# 140922       en          history modern
# 144251       en  constitutional history
# 148533       en          history modern
#
#                                                   summary  \
# 21283   Chosen by Paul Auster from four thousand stori...
# 42322   Nature writings of Aldo Leopold, one of the fo...
# 50689   Originally published in 1983 and named one of ...
# 55195   Covers each period, including events and indiv...
# 55912   This lavishly-illustrated book gives you a fro...
# 62387   Spanning from ancient Greece to the end of the...
# 73667   The text looks at the background of natural sc...
# 83784   A selection of 150 years worth of internationa...
# 90926   The author of Return of the Bird Tribes shares...
# 105275  A new edition to the breathtaking photography ...
# 105459  Edwin Way Teale&#39;s account of his 19,000-mi...
# 130965  Scholars have long regarded this work as a mil...
# 131743  A treasury of games and activities for both ad...
# 133767  This new edition of the best-selling courseboo...
# 140026  The murder of a wealthy, fashionable doctor an...
# 140922  A historical survey of Europe, Asia, Africa, a...
# 144251  No one can read the story that Richard Morris ...
# 148533  In 640 pages of color illustrations, maps, and...
#
#                  high_category
# 21283             oral history
# 42322          natural history
# 50689           history modern
# 55195            world history
# 55912           history modern
# 62387            world history
# 73667          natural history
# 83784           history modern
# 90926          natural history
# 105275            history asia
# 105459         natural history
# 130965  constitutional history
# 131743         natural history
# 133767          history modern
# 140026          history modern
# 140922          history modern
# 144251  constitutional history
# 148533          history modern

# %%
# 치환 코드. history

lst = ['histo', 'folk']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'history', inplace=True)

# %%
# 내용물을 들여다 보는 코드 이제 자연
(books[books['high_category'].str.contains('art') \
	& (books['high_category'] != 'art') \
	& (books['high_category'] != 'language arts disciplines') \
	& (books['high_category'] != 'performing arts') \
	# & (books['category'].str.contains('men') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 962     0449911683                               My Name Is Asher Lev
# 1105    2857043821                                  Le cycle du Graal
# 1700    0330262130              Restaurant At the End of the Universe
# 3783    0553289640                                      Body of Truth
# 3969    0394756827       Godel, Escher, Bach: An Eternal Golden Braid
# ...            ...                                                ...
# 145991  082122042X  The Chronicle of Impressionism: A Timeline His...
# 146430  0445046562                                   Thursday's Child
# 146930  3499505363              Die Dadaisten (Rowohlts Monographien)
# 148259  0152595805                                 The Patchwork Lady
# 148778  1869928318  Pan's Daughter - the magical world of Roseleen...
#
#                   book_author  year_of_publication                  publisher  \
# 962               Chaim Potok               1996.0           Ballantine Books
# 1105             Jean Markale               1992.0  Pygmalion/GÃ©rard Watelet
# 1700            Douglas Adams               1994.0              Pan Books Ltd
# 3783            David Lindsey               1993.0               Bantam Books
# 3969    Douglas R. Hofstadter               1989.0          Vintage Books USA
# ...                       ...                  ...                        ...
# 145991         Bernard Denvir               1993.0          Little Brown & Co
# 146430         Victoria Poole               1981.0               Warner Books
# 146930          Hermann Korte               1994.0                    Rowohlt
# 148259    Mary K. Whittington               1991.0                   Harcourt
# 148778           Nevill Drury               1995.0         Mandrake of Oxford
#
#        language                            category  \
# 962          en                             artists
# 1105         fr                  arthurian romances
# 1700         en    dent arthur fictitious character
# 3783         en  haydon stuart fictitious character
# 3969         en             artificial intelligence
# ...         ...                                 ...
# 145991       en                          art modern
# 146430       en                               heart
# 146930       de                         arts modern
# 148259       en                    birthday parties
# 148778       en                             artists
#
#                                                   summary  \
# 962     The novelist records the anguish and triumphs ...
# 1105    &quot;Jean Markale propose, dans le langage d&...
# 1700    Among Arthur&#39;s motley shipmates are Ford P...
# 3783    Well. Body of Truth is a brilliant thriller: l...
# 3969    Explores the mystery and complexity of human t...
# ...                                                   ...
# 145991  An illustrated chronicle of the artists, paint...
# 146430  A young man&#39;s heroic fight for life and th...
# 146930  Eine Kunst? Eine Philosophie? Eine Politik? Ei...
# 148259  The Patchwork Lady prepares her colorful patch...
# 148778  This is the first account of her life as a who...
#
#                              high_category
# 962                                artists
# 1105                    arthurian romances
# 1700      dent arthur fictitious character
# 3783    haydon stuart fictitious character
# 3969               artificial intelligence
# ...                                    ...
# 145991                          art modern
# 146430                               heart
# 146930                         arts modern
# 148259                    birthday parties
# 148778                             artists
#
# [184 rows x 9 columns]

# %%
# 치환 코드. art

lst = ['art', 'music', 'draw']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'art', inplace=True)

# %%
# 내용물을 들여다 보는 코드 이제 자연
(books[books['high_category'].str.contains('litera') \
	& (books['high_category'] != 'literary criticism') \
	& (books['high_category'] != 'literary collections') \
	# & (books['high_category'] != 'performing arts') \
	# & (books['category'].str.contains('men') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 545     0380711109                           Desert Notes/River Notes
# 672     0679733825  Sisters of the Earth: Women's Prose and Poetry...
# 981     0140430091        The History of Tom Jones (Penguin Classics)
# 1331    0140274154                 On the Road (Essential.penguin S.)
# 1970    2266000489                                  La Nuit Des Temps
# ...            ...                                                ...
# 144372  0307117413  Horses and Ponies (Golden Look-Look Books (Pap...
# 144820  8474237211                    Las Escritoras de La Edad Media
# 146669  0517604426                 Middle Ages (Myths&Legends Series)
# 148797  3312001374                           Der Riese im Baum: Roman
# 148972  0452272521  Flesh and the Word 3: An Anthology of Gay Erot...
#
#               book_author  year_of_publication                  publisher  \
# 545           Barry Lopez               1990.0      Quill (HarperCollins)
# 672     Lorraine Anderson               1991.0          Vintage Books USA
# 981        Henry Fielding               1985.0              Penguin Books
# 1331         Jack Kerouac               1998.0          Penguin Books Ltd
# 1970        Rene Barjavel               1994.0  Presses De La Cite French
# ...                   ...                  ...                        ...
# 144372     Rosanna Hansen               1990.0               Golden Books
# 144820       Peter Dronke               1997.0                   Grijalbo
# 146669      H. A. Guerber               1975.0             Crescent Books
# 148797     Eveline Hasler               1988.0             Nagel & Kimche
# 148972       John Preston               1995.0                Plume Books
#
#        language                category  \
# 545          en     american literature
# 672          en     american literature
# 981          en      canon literarature
# 1331         en     american literature
# 1970         fr       french literature
# ...         ...                     ...
# 144372       en   children s literature
# 144820       es     european literature
# 146669       en  chivalry in literature
# 148797       de        swiss literature
# 148972       en     american literature
#
#                                                   summary  \
# 545     Here, for the first time in one volume, are tw...
# 672     This book introduces us to female perspectives...
# 981     &quot;A foundling of mysterious parentage brou...
# 1331    Fictionalized narrative of travels by Kerouac ...
# 1970     L&#39;Antarctique peut révéler bien des secrets.
# ...                                                   ...
# 144372  Briefly describes the different types of horse...
# 144820  El exito obtenido por la Historia del tiempo, ...
# 146669  Contains a collection of famous European tales...
# 148797  Het leven van een Zwitserse reus, die in de tw...
# 148972  Anne Rice (writing as Anne Rampling), Aaron Sc...
#
#                  high_category
# 545        american literature
# 672        american literature
# 981         canon literarature
# 1331       american literature
# 1970         french literature
# ...                        ...
# 144372   children s literature
# 144820     european literature
# 146669  chivalry in literature
# 148797        swiss literature
# 148972     american literature
#
# [193 rows x 9 columns]

# %%
# 치환 코드. children

lst = ['child']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'children', inplace=True)

# %%
# 치환 코드. poetry

lst = ['poet']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'poetry', inplace=True)

# %%
# 치환 코드. drama

lst = ['drama', 'comedy', 'tragedy']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'drama', inplace=True)

# %%
# 치환 코드. literature

lst = ['litera']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'literature', inplace=True)

# %%
# 내용물을 들여다 보는 코드 이제 자연
(books[books['high_category'].str.contains('recreat') \
	& (books['high_category'] != 'sports recreation') \
	& (books['high_category'] != 'gardens') \
	# & (books['high_category'] != 'performing arts') \
	# & (books['category'].str.contains('dis') == True) \
	# & (books['category'].str.contains('juvenile') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 41940   0801978157  Chilton's Truck and Van Repair Manual, 1982-88...
# 47197   033048172X                                Absolutely Mental 1
# 102635  1559501324           Travel-Trailer Homesteading Under $5,000
# 120647  0934798443                                    The Rv Handbook
#
#              book_author  year_of_publication  \
# 41940     Alan F. Turner               1988.0
# 47197     Rowland Morgan               2000.0
# 102635  Brian D. Kelling               1999.0
# 120647        Bill Estes               1997.0
#
#                                   publisher language  \
# 41940   Motor Information Systems (Chilton)       en
# 47197                         Pan Macmillan       en
# 102635             Breakout Productions Inc       en
# 120647                       Pub Group West       en
#
#                            category  \
# 41940         recreational vehicles
# 47197      mathematical recreations
# 102635  recreational vehicle living
# 120647        recreational vehicles
#
#                                                   summary  \
# 41940   U.S., Canadian and import pick-ups, vans, RVs ...
# 47197   A collection of mathematical puzzles intended ...
# 102635  This is probably the most important section in...
# 120647  An indispensable guide to all types of RVS and...
#
#                       high_category
# 41940         recreational vehicles
# 47197      mathematical recreations
# 102635  recreational vehicle living
# 120647        recreational vehicles

# %%
# 치환 코드. philosophy

lst = ['philo']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'philosophy', inplace=True)

# %%
# 치환 코드. cook

lst = ['cook', 'food']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'cook', inplace=True)

# %%
# 치환 코드. crime

lst = ['crim', 'homi', 'murder']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'crime', inplace=True)

# %%
# 치환 코드. photo

lst = ['photo']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'photo', inplace=True)

# %%
# 치환 코드. hobby

lst = ['craft', 'hand', 'garden', 'sports', 'recreat']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'hobby', inplace=True)

# %%
# 내용물을 들여다 보는 코드 이제 자연
(books[books['high_category'].str.contains('game') \
	& (books['high_category'] != 'games') \
	& (books['high_category'] != 'games activities') \
	# & (books['high_category'] != 'performing arts') \
	# & (books['category'].str.contains('dis') == True) \
	# & (books['category'].str.contains('psychology') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 12408   0590262173  The Case of the Chocolate Fingerprints (Clue Jr.)
# 16349   0966961706                  Game Over Press Start To Continue
# 28596   059056871X   Death Comes to Dinner (Scene of the Crime, No 1)
# 35148   0935696016  Player's Handbook (Advanced Dungeons & Dragons...
# 37320   0590456334      Mystery at the Masked Ball (Clue Books, No 4)
# 37907   0590456326   The Case of the Invisible Cat (Clue Books, No 3)
# 40264   0590679104                                            Jumanji
# 40764   1889752061               Bicycle Official Rules of Card Games
# 46930   0688118461                                    Finders Keepers
# 56490   0590906100                   Jumanji: A Storybook (Storybook)
# 56564   0962467650  Awesome Sega Genesis Secrets II (Gaming Master...
# 56574   157840990X  WWF War Zone Official Strategy Guide for PlayS...
# 56587   1884364411                         Star Fox 64 Survival Guide
# 67735   0933635559  Cthulhu by Gaslight: Horror Roleplaying in the...
# 67751   1568820682  Horror's Heart: A Short Call of Cthulhu Campai...
# 69284   1568820569              Utatti Asfet: The Eye of Wicked Sight
# 69285   1568820615  The Art of Playing Mythos the Cthulhu Collecta...
# 71271   1580420117       Winning Casino Blackjack For The Non-Counter
# 83452   1555214134                                         Shoot Pool
# 90249   1565040295                  Vampire: The Masquerade (Vampire)
# 97767   076153007X  The Legend of Dragoon: Prima's Official Strate...
# 97939   1555601561                       Shadowtech (Shadowrun, 7110)
# 97972   1565040244                The Storytellers Handbook (Vampire)
# 97975   1565040422            A Players Guide to the Sabbat (Vampire)
# 97977   156504052X  Clanbook: Malkavian (Vampire: The Masquerade N...
# 97978   1565040538                    Vampire Players Guide (Vampire)
# 97979   1565040546  The Storytellers Handbook to the Sabbat (Sourc...
# 97984   1565040953  Clanbook: Toreador (Vampire: The Masquerade No...
# 97987   1565041151                                  Clanbook: Tremere
# 97988   1565041194  The Book of Shadows: The Mage Players Guide : ...
# 97990   1565041291                    Clanbook: Ventrue (Clan Series)
# 97994   1565042115                                 Clanbook: Lasombra
# 97996   1565042158                                    Clanbook Setite
# 98001   1565044002                         Mage: The Ascension (Mage)
# 98007   1565047001  Changeling-The Dreaming: A Storytelling Game o...
# 100579  0425112314             A Spy in Isengard (Middle-Earth Quest)
# 100596  0880384522  Dragonlance Adventures (Advanced Dungeons and ...
# 105006  1889546348                                    The Wasted West
# 110931  1565042751                             Vampire: The Dark Ages
# 113418  0880380209                              Revolt of the Dwarves
# 139899  0960761802                       Winning Casino Blackjack for
#
#                                book_author  year_of_publication  \
# 12408                     Parker C. Hinter               1997.0
# 16349                          David Sheff               1999.0
# 28596                        Marvin Miller               1995.0
# 35148                           Gary Gygax               1978.0
# 37320                          A.E. Parker               1993.0
# 37907                          A.E. Parker               1992.0
# 40264                        Todd Strasser               1995.0
# 40764   United States Playing Card Company               1999.0
# 46930                          Emily Rodda               1993.0
# 56490                         A. L. Singer               1995.0
# 56564                    J. Douglas Arnold               1993.0
# 56574                          Bill Kunkel               1998.0
# 56587                    J. Douglas Arnold               1998.0
# 67735                    William A. Barton               1988.0
# 67751                      Sheldon Gillett               1996.0
# 69284                         Owen Guthrie               1996.0
# 69285               Scott David Aniolowski               1996.0
# 71271                        Avery Cardoza               1992.0
# 83452                          Ian Pannell               1993.0
# 90249                      Mark Rein-Hagen               1995.0
# 97767                 Dimension Publishing               2000.0
# 97939                              Karl Wu               1993.0
# 97972                          Tony Harris               1995.0
# 97975                      Steven C. Brown               1995.0
# 97977                     Daniel Greenberg               1995.0
# 97978                     Andrew Greenberg               1993.0
# 97979                      Steven C. Brown               1995.0
# 97984                      Steven C. Brown               1995.0
# 97987                         Keith Herber               1995.0
# 97988                         Phil Brucato               1995.0
# 97990                     Andrew Greenberg               1995.0
# 97994                       Richard Dansky               1996.0
# 97996                        Richard Watts               1995.0
# 98001                         Phil Brucato               1995.0
# 98007                      Mark Rein-Hagen               1995.0
# 100579                        Terry Amthor               1988.0
# 100596                       Tracy Hickman               1987.0
# 105006                  Shane Lacy Hensley               1998.0
# 110931                  Jennifer Hartshorn               1996.0
# 113418                          Rose Estes               1983.0
# 139899                       Avery Cardoza               1989.0
#
#                                       publisher language  \
# 12408                                Scholastic       en
# 16349                   Cyberactive Media Group       en
# 28596                Scholastic Paperbacks (Mm)       en
# 35148   Distributed in the U.S. by Random House       en
# 37320                Scholastic Paperbacks (Mm)       en
# 37907                Scholastic Paperbacks (Mm)       en
# 40264                Scholastic Paperbacks (Mm)       en
# 40764        United States Playing Card Company       en
# 46930              Harpercollins Juvenile Books       en
# 56490                 Scholastic Paperbacks (T)       en
# 56564               Sandwich Islands Publishing       en
# 56574                             Acclaim Books       en
# 56587               Sandwich Islands Publishing       en
# 67735                            Chaosium, Inc.       en
# 67751                            Chaosium, Inc.       en
# 69284                            Chaosium, Inc.       en
# 69285                            Chaosium, Inc.       en
# 71271                               Cardoza Pub       en
# 83452                                Book Sales       en
# 90249                            White Wolf Pub       en
# 97767                          Prima Lifestyles       en
# 97939                  McGraw-Hill/Contemporary       en
# 97972                            White Wolf Pub       en
# 97975                            White Wolf Pub       en
# 97977                            White Wolf Pub       en
# 97978                            White Wolf Pub       en
# 97979                            White Wolf Pub       en
# 97984                            White Wolf Pub       en
# 97987                            White Wolf Pub       en
# 97988                   White Wolf Games Studio       en
# 97990                            White Wolf Pub       en
# 97994                            White Wolf Pub       en
# 97996                            White Wolf Pub       en
# 98001                            White Wolf Pub       en
# 98007                            White Wolf Pub       en
# 100579                 Berkley Publishing Group       en
# 100596                     Wizards of the Coast       en
# 105006             Pinnacle Entertainment Group       en
# 110931                  White Wolf Games Studio       en
# 113418                     Wizards of the Coast       en
# 139899                       Cardoza Publishing       en
#
#                          category  \
# 12408                   clue game
# 16349   electronic games industry
# 28596             adventure games
# 35148   dungeons and dragons game
# 37320                   clue game
# 37907                   clue game
# 40264                 board games
# 40764                  card games
# 46930                  game shows
# 56490                 board games
# 56564           sega genesis game
# 56574        nintendo video games
# 56587            star fox 64 game
# 67735         call of cthulu game
# 67751        call of cthulhu game
# 69284        call of cthulhu game
# 69285                  card games
# 71271              blackjack game
# 83452                   pool game
# 90249               fantasy games
# 97767                 video games
# 97939               fantasy games
# 97972               fantasy games
# 97975               fantasy games
# 97977               fantasy games
# 97978                vampire game
# 97979               fantasy games
# 97984               fantasy games
# 97987               fantasy games
# 97988                   mage game
# 97990               fantasy games
# 97994               fantasy games
# 97996               fantasy games
# 98001               fantasy games
# 98007               fantasy games
# 100579              fantasy games
# 100596  dungeons and dragons game
# 105006             deadlands game
# 110931               vampire game
# 113418  dungeons and dragons game
# 139899             blackjack game
#
#                                                   summary  \
# 12408   Another eight cases featuring the popular char...
# 16349   How did a Japanese company that once manufactu...
# 28596   Ten short crime stories offer readers a chance...
# 35148   Presents an introduction to Dungeons and Drago...
# 37320     Miss Scarlet, Mr. Greene, Colonel Mustard, Mrs.
# 37907   Mr. Boddy&#39;s six best friends--Miss Scarlet...
# 40264   Trapped in an extraordinary world after starti...
# 40764   All you need is this book and a deck of Bicycl...
# 46930   While playing a computer game, Patrick is tran...
# 56490   Trapped in an extraordinary world after starti...
# 56564   This great guide continues the tradition estab...
# 56574   Author Bill Kunkel, former editor of Main Even...
# 56587   The Star Fox sequel promises to be a mass-mark...
# 67735   &quot;Cthulhu by Gaslight&quot; includes a len...
# 67751   This 80 page book contains about twenty handou...
# 69284   A globe-trotting campaign for Call of Cthulhu....
# 69285   &quot;Mythos&quot; is the most innovative coll...
# 71271   Revised and expanded with the latest coverage ...
# 83452   Chapters are divided into The Equipment, The S...
# 90249   What are we? The Damned childer of Caine? The ...
# 97767   Gamers assume the role of young Dart, who must...
# 97939          Personal-technology sourcebook: Shadowrun.
# 97972   Only one individual knows all the secrets of t...
# 97975   The most feared undead in existence, the Sabba...
# 97977   Clanbook: Malkavian presents this special clan...
# 97978   This revised book of character information int...
# 97979   A Players Guide to the Sabbat introduced this ...
# 97984   With one foot in the world of the undead and o...
# 97987   Born of murder and greed, created for power an...
# 97988   In this Book of Shadows, mage players and Stor...
# 97990   The last of the Camarilla Clanbooks is reserve...
# 97994   Masters of deception and intrigue, the Lasombr...
# 97996   Now the Setites reveal why they have taken the...
# 98001   The third game in the STORYTELLER series delve...
# 98007                    Spillelederens og spillerens bog
# 100579  In A Spy in Isengard, corruption by dark power...
# 100596  Details the background, characters, magic weap...
# 105006  The world is in ruins and the Reckoners are wa...
# 110931  In the WORLD OF DARKNESS series, this book inc...
# 113418  The reader&#39;s choices determine the outcome...
# 139899  Revised and expanded with the latest coverage ...
#
#                     high_category
# 12408                   clue game
# 16349   electronic games industry
# 28596             adventure games
# 35148   dungeons and dragons game
# 37320                   clue game
# 37907                   clue game
# 40264                 board games
# 40764                  card games
# 46930                  game shows
# 56490                 board games
# 56564           sega genesis game
# 56574        nintendo video games
# 56587            star fox 64 game
# 67735         call of cthulu game
# 67751        call of cthulhu game
# 69284        call of cthulhu game
# 69285                  card games
# 71271              blackjack game
# 83452                   pool game
# 90249               fantasy games
# 97767                 video games
# 97939               fantasy games
# 97972               fantasy games
# 97975               fantasy games
# 97977               fantasy games
# 97978                vampire game
# 97979               fantasy games
# 97984               fantasy games
# 97987               fantasy games
# 97988                   mage game
# 97990               fantasy games
# 97994               fantasy games
# 97996               fantasy games
# 98001               fantasy games
# 98007               fantasy games
# 100579              fantasy games
# 100596  dungeons and dragons game
# 105006             deadlands game
# 110931               vampire game
# 113418  dungeons and dragons game
# 139899             blackjack game

# %%
# 치환 코드. travel

lst = ['travel']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'travel', inplace=True)

# %%
# 치환 코드. adventure

lst = ['adventure']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'adventure', inplace=True)

# %%
# 치환 코드. psycho

lst = ['psycho']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'psychology', inplace=True)

# %%
# 치환 코드. comic

lst = ['comic']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'comic', inplace=True)

# %%
# 치환 코드. education

lst = ['educ']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'education', inplace=True)

# %%
# 치환 코드. mystery

lst = ['myster', 'detect']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'mystery', inplace=True)

# %%
# 치환 코드. horror

lst = ['horror']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'horror', inplace=True)

# %%
# 치환 코드. law

lst = ['law']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'law', inplace=True)

# %%
# 치환 코드. game

lst = ['game']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'game', inplace=True)

# %%
# 내용물을 들여다 보는 코드 마지막으로 나라
(books[books['high_category'].str.contains('broth') \
	& (books['high_category'] != 'games') \
	& (books['high_category'] != 'games activities') \
	# & (books['high_category'] != 'performing arts') \
	# & (books['category'].str.contains('dis') == True) \
	# & (books['category'].str.contains('psychology') == False) \
	])\
	# .sample(10)
# Out:
#               isbn                                         book_title  \
# 82      0553062042                Daybreakers Louis Lamour Collection
# 1500    0449700712                                        Diceys Song
# 1725    0752853007                                       The Ex-files
# 3147    0812533550      Ender's Game (Ender Wiggins Saga (Paperback))
# 3367    0590448285  Karen's Tea Party (Baby-Sitters Little Sister,...
# ...            ...                                                ...
# 144310  0937295817  Meet Molly, an American Girl (American Girls C...
# 146798  0862782066                            Under the Hawthorn Tree
# 147092  0816743274                       Wild America: A Novelization
# 147665  1869414756                                        Little moon
# 148133  0733608361                          The Tazyrik year: A novel
#
#                   book_author  year_of_publication  \
# 82               Louis Lamour               1981.0
# 1500            Cynthia Voigt               1984.0
# 1725               Jane Moore               2003.0
# 3147         Orson Scott Card               1986.0
# 3367            Ann M. Martin               1992.0
# ...                       ...                  ...
# 144310          Valerie Tripp               1990.0
# 146798  Marita Conlon-McKenna               2001.0
# 147092             Ron Fontes               1997.0
# 147665             Emma Neale               2001.0
# 148133             Alan Gould               1998.0
#
#                             publisher language              category  \
# 82              Bantam Doubleday Dell       en              brothers
# 1500                 Ballantine Books       en  brothers and sisters
# 1725                            Orion       en              brothers
# 3147                        Tor Books       en  brothers and sisters
# 3367                       Scholastic       en  brothers and sisters
# ...                               ...      ...                   ...
# 144310  Pleasant Company Publications       en  brothers and sisters
# 146798                  O'Brien Press       en  brothers and sisters
# 147092           Troll Communications       en              brothers
# 147665                        Vintage       en  brothers and sisters
# 148133                        Sceptre       en  brothers and sisters
#
#                                                   summary  \
# 82      Tyrel and Orrin Sackett travel from Tennessee ...
# 1500    Letting GoThe four Tillerman children finally ...
# 1725    THE EX-FILES is a bracing, witty look at conte...
# 3147    The Hugo and Nebula Award-winning classic is n...
# 3367    Sent to charm school to learn how to improve h...
# ...                                                   ...
# 144310  While her fatheris away in the war, Molly find...
# 146798  When their father and mother go missing in the...
# 147092  In 1968, three brothers film America&#39;s van...
# 147665  The intensity and dependency of this relations...
# 148133  Novel dealing with the secret lives of a broth...
#
#                high_category
# 82                  brothers
# 1500    brothers and sisters
# 1725                brothers
# 3147    brothers and sisters
# 3367    brothers and sisters
# ...                      ...
# 144310  brothers and sisters
# 146798  brothers and sisters
# 147092              brothers
# 147665  brothers and sisters
# 148133  brothers and sisters
#
# [122 rows x 9 columns]

# %%
# 치환 코드. country, 미국만 따로 처리. 
lst = ['brita', 'engla', 'canada', 'africa', 'gree', 'asia', 'europ', 'nethe', 'korea',\
			'norwa', 'zeala', 'denmark', 'german', 'deutsch', 'russ', 'roman', 'mala', 'mexi',\
			'mong', 'viet', 'belg', 'braz', 'spain', 'singap', 'argen', 'irelan', 'austr', \
			'iran', 'isra', 'egyp', 'ital', 'india', 'indo', 'japan', 'china', 'chinese', 'portu', \
			'polan', 'fran', 'finlan', 'hunga']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'country', inplace=True)

# %%
# 치환 코드. 미국
lst = ['united', 'ameri']
lst = '|'.join(lst)
books['high_category'].where(books['category'].str.contains(lst)==False, 'america', inplace=True)

# %%
ans = 0
for i in ((books['high_category'].value_counts())):
	if i < 50: ans +=1
print(ans)
#10개 이하는 범주도 아니라고 쳐보자고.
# Out:
# 2546

# %%
category_high_df = pd.DataFrame(books['high_category'].value_counts()).reset_index()
category_high_df.columns = ['category','count']
others_list = category_high_df[category_high_df['count']<10]['category'].values
# books['high_category']
books['high_category'].where(books['high_category'].isin(others_list) == False, 'others', inplace=True)

# %%
import os
if not os.path.isfile('/opt/ml/input/code/books.csv'):
	books.to_csv('/opt/ml/input/code/books.csv', index=False)

# %%
((books['high_category'].value_counts()))#[1:].sum()
# Out:
# 1                       68851
# fiction                 33469
# juvenile                 7314
# others                   4423
# biography                3350
#                         ...
# intelligence service       10
# chicago ill                10
# arizona                    10
# dreams                     10
# bedtime                    10
# Name: high_category, Length: 154, dtype: int64

# %%
mine = ['juvenile' ,'fiction', 'religion','biography', 'humor' ,'meditation', 'social', 'politic',
		'science', 'computer', 'economy', 'family', 'health', 'animal', 'nature', 'history', 'art',
		'children', 'poetry', 'drama', 'literature', 'philosophy', 'cook', 'crime', 'photo', 'hobby',
		'travel', 'adventure', 'psychology', 'comic', 'reference', 'education', 'mystery', 'horror',
		'law', 'game', 'country', 'america', 'others']


categories = ['garden','crafts','physics','adventure','music','fiction','nonfiction','science','science fiction','social','homicide',
 'sociology','disease','religion','christian','philosophy','psycholog','mathemat','agricult','environmental',
 'business','poetry','drama','literary','travel','motion picture','children','cook','literature','electronic',
 'humor','animal','bird','photograph','computer','house','ecology','family','architect','camp','criminal','language','india',
 'history']

# %% [markdown]
# # 여태 만든 범주로, 분포따라 범주 결측치 메꿔보기

# %%
#나이를 메꾸듯이 범주를 메꿔볼까?
cate_exist = books[books['high_category'] != '1']['high_category'].tolist()
cate_exist
# Out:
# ['actresses',
#  'others',
#  'medical',
#  'fiction',
#  'history',
#  'fiction',
#  'fiction',
#  'nature',
#  'fiction',
#  'fiction',
#  'fiction',
#  'humor',
#  'cook',
#  'reference',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'history',
#  'fiction',
#  'fiction',
#  'health',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'psychology',
#  'fiction',
#  'fiction',
#  'others',
#  'juvenile',
#  'fiction',
#  'science',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'humor',
#  'history',
#  'conduct of life',
#  'fiction',
#  'horses',
#  'fiction',
#  'fiction',
#  'science',
#  'brothers',
#  'fiction',
#  'baggins frodo fictitious character',
#  'baggins frodo fictitious character',
#  'history',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'economy',
#  'economy',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'humor',
#  'america',
#  'others',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'literature',
#  'fiction',
#  'meditation',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'america',
#  'biography',
#  'fiction',
#  'humor',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'religion',
#  'fiction',
#  'fiction',
#  'america',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'biography',
#  'country',
#  'fiction',
#  'meditation',
#  'fiction',
#  'fiction',
#  'humor',
#  'fiction',
#  'country',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'science',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'juvenile',
#  'science',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'others',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'adolescence',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'dune imaginary place',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'animal',
#  'fiction',
#  'country',
#  'fiction',
#  'juvenile',
#  'country',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'art',
#  'fiction',
#  'others',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fairy tales',
#  'fiction',
#  'america',
#  'juvenile',
#  'children',
#  'others',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'juvenile',
#  'biography',
#  'biography',
#  'fiction',
#  'biography',
#  'fiction',
#  'poetry',
#  'fiction',
#  'comic',
#  'comic',
#  'fiction',
#  'fiction',
#  'comic',
#  'comic',
#  'art',
#  'comic',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'fiction',
#  'biography',
#  'religion',
#  'country',
#  'fiction',
#  'juvenile',
#  'others',
#  'others',
#  'family',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'computer',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'nature',
#  'fiction',
#  'fiction',
#  'america',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'economy',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'biography',
#  'psychology',
#  'juvenile',
#  'juvenile',
#  'health',
#  'health',
#  'health',
#  'health',
#  'health',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'science',
#  'nature',
#  'fiction',
#  'meditation',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'literature',
#  'biography',
#  'science',
#  'biography',
#  'biography',
#  'meditation',
#  'women',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'families',
#  'humor',
#  'animal',
#  'crime',
#  'others',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'economy',
#  'game',
#  'fiction',
#  'fiction',
#  'america',
#  'religion',
#  'fiction',
#  'meditation',
#  'humor',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'history',
#  'fiction',
#  'fiction',
#  'cook',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'poetry',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'poetry',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'presidents',
#  'health',
#  'health',
#  'family',
#  'education',
#  'fiction',
#  'fiction',
#  'mystery',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'poetry',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fantasy',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'psychology',
#  'fiction',
#  'reference',
#  'courage',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'science',
#  'health',
#  'biography',
#  'science',
#  'horror',
#  'others',
#  'fiction',
#  'fiction',
#  'fiction',
#  'economy',
#  'fiction',
#  'science',
#  'juvenile',
#  'science',
#  'juvenile',
#  'fiction',
#  'philosophy',
#  'others',
#  'others',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'dinosaurs',
#  'juvenile',
#  'fiction',
#  'health',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'adventure',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'humor',
#  'family',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'science',
#  'science',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'fiction',
#  'others',
#  'technology engineering',
#  'fiction',
#  'economy',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'religion',
#  'economy',
#  'fiction',
#  'science',
#  'fiction',
#  'biography',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'art',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'literature',
#  'courtship',
#  'country',
#  'country',
#  'fiction',
#  'fiction',
#  'fiction',
#  'history',
#  'health',
#  'fiction',
#  'humor',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'meditation',
#  'juvenile',
#  'art',
#  'fiction',
#  'mystery',
#  'juvenile',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'fairy tales',
#  'reference',
#  'others',
#  'humor',
#  'children',
#  'science',
#  'cook',
#  'exercise',
#  'poetry',
#  'others',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'country',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'science',
#  'fiction',
#  'fiction',
#  'literature',
#  'fiction',
#  'fiction',
#  'fiction',
#  'humor',
#  'hobby',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'computer',
#  'education',
#  'humor',
#  'history',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'fantasy',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'others',
#  'religion',
#  'cook',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'history',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'fiction',
#  'biography',
#  'english language',
#  'medical',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'journalists',
#  'fiction',
#  'authorship',
#  'juvenile',
#  'medical',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'actors',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'science',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'art',
#  'fiction',
#  'health',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'history',
#  'history',
#  'fiction',
#  'crime',
#  'fiction',
#  'travel',
#  'fiction',
#  'fiction',
#  'fiction',
#  'humor',
#  'country',
#  'fiction',
#  'america',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'country',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'america',
#  'california',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'science',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'poetry',
#  'fiction',
#  'meditation',
#  'animal',
#  'others',
#  'art',
#  'hobby',
#  'fiction',
#  'fiction',
#  'america',
#  'computer',
#  'fiction',
#  'juvenile',
#  'fiction',
#  'science',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'country',
#  'philosophy',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'others',
#  'fiction',
#  'fiction',
#  'health',
#  'blind',
#  'juvenile',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'history',
#  'psychology',
#  'history',
#  'humor',
#  'fiction',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'mystery',
#  'fiction',
#  'country',
#  'others',
#  'fiction',
#  'fiction',
#  'brothers and sisters',
#  'drama',
#  'others',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'animal',
#  'others',
#  'juvenile',
#  'juvenile',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'mystery',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'religion',
#  'others',
#  'country',
#  'fiction',
#  'fiction',
#  'america',
#  'fiction',
#  'life on other planets',
#  'others',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'juvenile',
#  'fiction',
#  'literature',
#  'fiction',
#  'fiction',
#  'religion',
#  'fiction',
#  'literature',
#  'christmas stories',
#  'biography',
#  'art',
#  'fiction',
#  'fiction',
#  'fiction',
#  'fairies',
#  'others',
#  'country',
#  'fiction',
#  'history',
#  'medical',
#  'fiction',
#  'humor',
#  'biography',
#  'fiction',
#  'fiction',
#  'fiction',
#  'juvenile',
#  'humor',
#  'others',
#  'fiction',
#  'fiction',
#  'fiction',
#  'others',
#  'fiction',
#  'fiction',
#  'biography',
#  'religion',
#  'others',
#  'fiction',
#  'crime',
#  'science',
#  'juvenile',
#  'humor',
#  'meditation',
#  'fiction',
#  'fiction',
#  'biography',
#  'fiction',
#  'fiction',
#  'economy',
#  'fiction',
#  'fiction',
#  ...]

# %%
# 범주 분포 기준으로 범주 결측치 메꾸기
# books[books['high_category'] == '1'] = books[books['high_category'] == '1'].apply(lambda x: np.random.choice(cate_exist))
# books['high_category'].where(books['high_category'] != '1', np.random.choice(cate_exist), inplace=True)

for i, j in enumerate(books['high_category']):
	if j == '1':
		books['high_category'].iloc[i] = np.random.choice(cate_exist)


books['high_category'].value_counts()
# # books
# books['high_category'].iloc[2] = 'tras'
# books['high_category'][2]
# Out:
# 0
# /tmp/ipykernel_86700/949304661.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books['high_category'].iloc[i] = np.random.choice(cate_exist)
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300
# 37400
# 37500
# 37600
# 37700
# 37800
# 37900
# 38000
# 38100
# 38200
# 38300
# 38400
# 38500
# 38600
# 38700
# 38800
# 38900
# 39000
# 39100
# 39200
# 39300
# 39400
# 39500
# 39600
# 39700
# 39800
# 39900
# 40000
# 40100
# 40200
# 40300
# 40400
# 40500
# 40600
# 40700
# 40800
# 40900
# 41000
# 41100
# 41200
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# 42000
# 42100
# 42200
# 42300
# 42400
# 42500
# 42600
# 42700
# 42800
# 42900
# 43000
# 43100
# 43200
# 43300
# 43400
# 43500
# 43600
# 43700
# 43800
# 43900
# 44000
# 44100
# 44200
# 44300
# 44400
# 44500
# 44600
# 44700
# 44800
# 44900
# 45000
# 45100
# 45200
# 45300
# 45400
# 45500
# 45600
# 45700
# 45800
# 45900
# 46000
# 46100
# 46200
# 46300
# 46400
# 46500
# 46600
# 46700
# 46800
# 46900
# 47000
# 47100
# 47200
# 47300
# 47400
# 47500
# 47600
# 47700
# 47800
# 47900
# 48000
# 48100
# 48200
# 48300
# 48400
# 48500
# 48600
# 48700
# 48800
# 48900
# 49000
# 49100
# 49200
# 49300
# 49400
# 49500
# 49600
# 49700
# 49800
# 49900
# 50000
# 50100
# 50200
# 50300
# 50400
# 50500
# 50600
# 50700
# 50800
# 50900
# 51000
# 51100
# 51200
# 51300
# 51400
# 51500
# 51600
# 51700
# 51800
# 51900
# 52000
# 52100
# 52200
# 52300
# 52400
# 52500
# 52600
# 52700
# 52800
# 52900
# 53000
# 53100
# 53200
# 53300
# 53400
# 53500
# 53600
# 53700
# 53800
# 53900
# 54000
# 54100
# 54200
# 54300
# 54400
# 54500
# 54600
# 54700
# 54800
# 54900
# 55000
# 55100
# 55200
# 55300
# 55400
# 55500
# 55600
# 55700
# 55800
# 55900
# 56000
# 56100
# 56200
# 56300
# 56400
# 56500
# 56600
# 56700
# 56800
# 56900
# 57000
# 57100
# 57200
# 57300
# 57400
# 57500
# 57600
# 57700
# 57800
# 57900
# 58000
# 58100
# 58200
# 58300
# 58400
# 58500
# 58600
# 58700
# 58800
# 58900
# 59000
# 59100
# 59200
# 59300
# 59400
# 59500
# 59600
# 59700
# 59800
# 59900
# 60000
# 60100
# 60200
# 60300
# 60400
# 60500
# 60600
# 60700
# 60800
# 60900
# 61000
# 61100
# 61200
# 61300
# 61400
# 61500
# 61600
# 61700
# 61800
# 61900
# 62000
# 62100
# 62200
# 62300
# 62400
# 62500
# 62600
# 62700
# 62800
# 62900
# 63000
# 63100
# 63200
# 63300
# 63400
# 63500
# 63600
# 63700
# 63800
# 63900
# 64000
# 64100
# 64200
# 64300
# 64400
# 64500
# 64600
# 64700
# 64800
# 64900
# 65000
# 65100
# 65200
# 65300
# 65400
# 65500
# 65600
# 65700
# 65800
# 65900
# 66000
# 66100
# 66200
# 66300
# 66400
# 66500
# 66600
# 66700
# 66800
# 66900
# 67000
# 67100
# 67200
# 67300
# 67400
# 67500
# 67600
# 67700
# 67800
# 67900
# 68000
# 68100
# 68200
# 68300
# 68400
# 68500
# 68600
# 68700
# 68800
# 68900
# 69000
# 69100
# 69200
# 69300
# 69400
# 69500
# 69600
# 69700
# 69800
# 69900
# 70000
# 70100
# 70200
# 70300
# 70400
# 70500
# 70600
# 70700
# 70800
# 70900
# 71000
# 71100
# 71200
# 71300
# 71400
# 71500
# 71600
# 71700
# 71800
# 71900
# 72000
# 72100
# 72200
# 72300
# 72400
# 72500
# 72600
# 72700
# 72800
# 72900
# 73000
# 73100
# 73200
# 73300
# 73400
# 73500
# 73600
# 73700
# 73800
# 73900
# 74000
# 74100
# 74200
# 74300
# 74400
# 74500
# 74600
# 74700
# 74800
# 74900
# 75000
# 75100
# 75200
# 75300
# 75400
# 75500
# 75600
# 75700
# 75800
# 75900
# 76000
# 76100
# 76200
# 76300
# 76400
# 76500
# 76600
# 76700
# 76800
# 76900
# 77000
# 77100
# 77200
# 77300
# 77400
# 77500
# 77600
# 77700
# 77800
# 77900
# 78000
# 78100
# 78200
# 78300
# 78400
# 78500
# 78600
# 78700
# 78800
# 78900
# 79000
# 79100
# 79200
# 79300
# 79400
# 79500
# 79600
# 79700
# 79800
# 79900
# 80000
# 80100
# 80200
# 80300
# 80400
# 80500
# 80600
# 80700
# 80800
# 80900
# 81000
# 81100
# 81200
# 81300
# 81400
# 81500
# 81600
# 81700
# 81800
# 81900
# 82000
# 82100
# 82200
# 82300
# 82400
# 82500
# 82600
# 82700
# 82800
# 82900
# 83000
# 83100
# 83200
# 83300
# 83400
# 83500
# 83600
# 83700
# 83800
# 83900
# 84000
# 84100
# 84200
# 84300
# 84400
# 84500
# 84600
# 84700
# 84800
# 84900
# 85000
# 85100
# 85200
# 85300
# 85400
# 85500
# 85600
# 85700
# 85800
# 85900
# 86000
# 86100
# 86200
# 86300
# 86400
# 86500
# 86600
# 86700
# 86800
# 86900
# 87000
# 87100
# 87200
# 87300
# 87400
# 87500
# 87600
# 87700
# 87800
# 87900
# 88000
# 88100
# 88200
# 88300
# 88400
# 88500
# 88600
# 88700
# 88800
# 88900
# 89000
# 89100
# 89200
# 89300
# 89400
# 89500
# 89600
# 89700
# 89800
# 89900
# 90000
# 90100
# 90200
# 90300
# 90400
# 90500
# 90600
# 90700
# 90800
# 90900
# 91000
# 91100
# 91200
# 91300
# 91400
# 91500
# 91600
# 91700
# 91800
# 91900
# 92000
# 92100
# 92200
# 92300
# 92400
# 92500
# 92600
# 92700
# 92800
# 92900
# 93000
# 93100
# 93200
# 93300
# 93400
# 93500
# 93600
# 93700
# 93800
# 93900
# 94000
# 94100
# 94200
# 94300
# 94400
# 94500
# 94600
# 94700
# 94800
# 94900
# 95000
# 95100
# 95200
# 95300
# 95400
# 95500
# 95600
# 95700
# 95800
# 95900
# 96000
# 96100
# 96200
# 96300
# 96400
# 96500
# 96600
# 96700
# 96800
# 96900
# 97000
# 97100
# 97200
# 97300
# 97400
# 97500
# 97600
# 97700
# 97800
# 97900
# 98000
# 98100
# 98200
# 98300
# 98400
# 98500
# 98600
# 98700
# 98800
# 98900
# 99000
# 99100
# 99200
# 99300
# 99400
# 99500
# 99600
# 99700
# 99800
# 99900
# 100000
# 100100
# 100200
# 100300
# 100400
# 100500
# 100600
# 100700
# 100800
# 100900
# 101000
# 101100
# 101200
# 101300
# 101400
# 101500
# 101600
# 101700
# 101800
# 101900
# 102000
# 102100
# 102200
# 102300
# 102400
# 102500
# 102600
# 102700
# 102800
# 102900
# 103000
# 103100
# 103200
# 103300
# 103400
# 103500
# 103600
# 103700
# 103800
# 103900
# 104000
# 104100
# 104200
# 104300
# 104400
# 104500
# 104600
# 104700
# 104800
# 104900
# 105000
# 105100
# 105200
# 105300
# 105400
# 105500
# 105600
# 105700
# 105800
# 105900
# 106000
# 106100
# 106200
# 106300
# 106400
# 106500
# 106600
# 106700
# 106800
# 106900
# 107000
# 107100
# 107200
# 107300
# 107400
# 107500
# 107600
# 107700
# 107800
# 107900
# 108000
# 108100
# 108200
# 108300
# 108400
# 108500
# 108600
# 108700
# 108800
# 108900
# 109000
# 109100
# 109200
# 109300
# 109400
# 109500
# 109600
# 109700
# 109800
# 109900
# 110000
# 110100
# 110200
# 110300
# 110400
# 110500
# 110600
# 110700
# 110800
# 110900
# 111000
# 111100
# 111200
# 111300
# 111400
# 111500
# 111600
# 111700
# 111800
# 111900
# 112000
# 112100
# 112200
# 112300
# 112400
# 112500
# 112600
# 112700
# 112800
# 112900
# 113000
# 113100
# 113200
# 113300
# 113400
# 113500
# 113600
# 113700
# 113800
# 113900
# 114000
# 114100
# 114200
# 114300
# 114400
# 114500
# 114600
# 114700
# 114800
# 114900
# 115000
# 115100
# 115200
# 115300
# 115400
# 115500
# 115600
# 115700
# 115800
# 115900
# 116000
# 116100
# 116200
# 116300
# 116400
# 116500
# 116600
# 116700
# 116800
# 116900
# 117000
# 117100
# 117200
# 117300
# 117400
# 117500
# 117600
# 117700
# 117800
# 117900
# 118000
# 118100
# 118200
# 118300
# 118400
# 118500
# 118600
# 118700
# 118800
# 118900
# 119000
# 119100
# 119200
# 119300
# 119400
# 119500
# 119600
# 119700
# 119800
# 119900
# 120000
# 120100
# 120200
# 120300
# 120400
# 120500
# 120600
# 120700
# 120800
# 120900
# 121000
# 121100
# 121200
# 121300
# 121400
# 121500
# 121600
# 121700
# 121800
# 121900
# 122000
# 122100
# 122200
# 122300
# 122400
# 122500
# 122600
# 122700
# 122800
# 122900
# 123000
# 123100
# 123200
# 123300
# 123400
# 123500
# 123600
# 123700
# 123800
# 123900
# 124000
# 124100
# 124200
# 124300
# 124400
# 124500
# 124600
# 124700
# 124800
# 124900
# 125000
# 125100
# 125200
# 125300
# 125400
# 125500
# 125600
# 125700
# 125800
# 125900
# 126000
# 126100
# 126200
# 126300
# 126400
# 126500
# 126600
# 126700
# 126800
# 126900
# 127000
# 127100
# 127200
# 127300
# 127400
# 127500
# 127600
# 127700
# 127800
# 127900
# 128000
# 128100
# 128200
# 128300
# 128400
# 128500
# 128600
# 128700
# 128800
# 128900
# 129000
# 129100
# 129200
# 129300
# 129400
# 129500
# 129600
# 129700
# 129800
# 129900
# 130000
# 130100
# 130200
# 130300
# 130400
# 130500
# 130600
# 130700
# 130800
# 130900
# 131000
# 131100
# 131200
# 131300
# 131400
# 131500
# 131600
# 131700
# 131800
# 131900
# 132000
# 132100
# 132200
# 132300
# 132400
# 132500
# 132600
# 132700
# 132800
# 132900
# 133000
# 133100
# 133200
# 133300
# 133400
# 133500
# 133600
# 133700
# 133800
# 133900
# 134000
# 134100
# 134200
# 134300
# 134400
# 134500
# 134600
# 134700
# 134800
# 134900
# 135000
# 135100
# 135200
# 135300
# 135400
# 135500
# 135600
# 135700
# 135800
# 135900
# 136000
# 136100
# 136200
# 136300
# 136400
# 136500
# 136600
# 136700
# 136800
# 136900
# 137000
# 137100
# 137200
# 137300
# 137400
# 137500
# 137600
# 137700
# 137800
# 137900
# 138000
# 138100
# 138200
# 138300
# 138400
# 138500
# 138600
# 138700
# 138800
# 138900
# 139000
# 139100
# 139200
# 139300
# 139400
# 139500
# 139600
# 139700
# 139800
# 139900
# 140000
# 140100
# 140200
# 140300
# 140400
# 140500
# 140600
# 140700
# 140800
# 140900
# 141000
# 141100
# 141200
# 141300
# 141400
# 141500
# 141600
# 141700
# 141800
# 141900
# 142000
# 142100
# 142200
# 142300
# 142400
# 142500
# 142600
# 142700
# 142800
# 142900
# 143000
# 143100
# 143200
# 143300
# 143400
# 143500
# 143600
# 143700
# 143800
# 143900
# 144000
# 144100
# 144200
# 144300
# 144400
# 144500
# 144600
# 144700
# 144800
# 144900
# 145000
# 145100
# 145200
# 145300
# 145400
# 145500
# 145600
# 145700
# 145800
# 145900
# 146000
# 146100
# 146200
# 146300
# 146400
# 146500
# 146600
# 146700
# 146800
# 146900
# 147000
# 147100
# 147200
# 147300
# 147400
# 147500
# 147600
# 147700
# 147800
# 147900
# 148000
# 148100
# 148200
# 148300
# 148400
# 148500
# 148600
# 148700
# 148800
# 148900
# 149000
# 149100
# 149200
# 149300
# 149400
# 149500
# fiction             62143
# juvenile            13504
# others               8203
# biography            6168
# science              4408
#                     ...
# readers                16
# college students       15
# dreams                 13
# fairies                13
# courage                13
# Name: high_category, Length: 153, dtype: int64

# %%
fig, ax= plt.subplots(1,1, figsize=(11,6))
ax = ax
my_dict= books['high_category'].value_counts().to_dict() #학습셋 내 범주 분포
count= pd.DataFrame(list(my_dict.items()),columns = ['category in books','count'])
f = count.sort_values(by=['count'], ascending = False)
f = f.head(15) #많은 국가 15개만
sns.barplot(y = 'count',x= 'category in books' , data = f, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=60,horizontalalignment='center')
for bar in ax.patches: 
    ax.annotate(format(bar.get_height(), '.0f'),  
                   (bar.get_x() + bar.get_width() / 2,  
                    bar.get_height()), ha='center', va='center', 
                   size=8, xytext=(0,8), 
                   textcoords='offset points') 

plt.show()

# %%
import os
if not os.path.isfile('/opt/ml/input/code/books_fillna_cate.csv'):
	books.to_csv('/opt/ml/input/code/books_fillna_cate.csv', index=False)
